# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Importing the Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.utils import image_dataset_from_directory

# %% [markdown]
# # Sample Image Visualizaiton

# %%
sample_image_path = '/content/gdrive/My Drive/ml project/muffin vs chihahua/train/chihuahua/img_0_198.jpg'

# Load the original image in RGB
original_image_rgb = cv2.imread(sample_image_path, cv2.IMREAD_COLOR)

# Resize the RGB image to 64x64 pixels
resized_rgb_64x64 = cv2.resize(original_image_rgb, (64, 64))

# Plot the images
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(original_image_rgb, cv2.COLOR_BGR2RGB))
plt.title('Original RGB Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(resized_rgb_64x64, cv2.COLOR_BGR2RGB))
plt.title('Resized RGB Image (64x64)')
plt.axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-16-d864c967c505> in <cell line: 1>()
# ----> 1 resized_rgb_64x64 = cv2.resize(original_image_rgb, (64, 64))
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/resize.cpp:4062: error: (-215:Assertion failed) !ssize.empty() in function 'resize'

# %% [markdown]
# # Loading the Dataset

# %%
# Define directories for train and test data
train_dir = '/content/gdrive/My Drive/ml project/muffin vs chihahua/train'
test_dir = '/content/gdrive/My Drive/ml project/muffin vs chihahua/test'

# Define image size
image_size = (64, 64)

# Load train and test datasets
train_dataset = image_dataset_from_directory(
    train_dir,
    image_size=image_size,
    batch_size=1,
    shuffle=True)

test_dataset = image_dataset_from_directory(
    test_dir,
    image_size=image_size,
    batch_size=1,
    shuffle=False)  # No need to shuffle test data

# Print class names
class_names = train_dataset.class_names
print("Class names:", class_names)
# Out:
# Found 14 files belonging to 2 classes.
# Found 306 files belonging to 2 classes.
# Class names: ['chihuahua', 'muffin']

# %% [markdown]
# # Splitting

# %%
# Extract images and labels from training data
train_images = []
train_labels = []
for images, labels in train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE):
    train_images.extend(images.numpy())
    train_labels.extend(labels.numpy())

# Extract images and labels from test data
test_images = []
test_labels = []
for images, labels in test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE):
    test_images.extend(images.numpy())
    test_labels.extend(labels.numpy())

# Convert lists to NumPy arrays
train_images = np.array(train_images)
train_labels = np.array(train_labels)
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %% [markdown]
# # Data Normalization

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

print("Shape of train_images:", train_images.shape)
print("Shape of train_labels:", train_labels.shape)
print("Shape of test_images:", test_images.shape)
print("Shape of test_labels:", test_labels.shape)

# %%
print(train_images.min())
print(train_images.max())

# %%
import random
import matplotlib.pyplot as plt

# Define the number of images to plot
num_images = 4

# Randomly select indices for the images
random_indices = random.sample(range(len(train_images)), num_images)

# Plot the images
plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(1, num_images, i+1)
    plt.imshow(train_images[idx])

    # Labeling
    numerical_label = train_labels[idx]
    if numerical_label == 1:
        label_name = "Muffin"
    else:
        label_name = "Chihuahua"

    plt.title("Label: {} ({})".format(label_name, numerical_label))
    plt.axis("off")

plt.show()

# %%
train_images[0]

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)

# %% [markdown]
# # Saving the Preprocessed Data

# %%
import pickle

# Specifying the directory
directory_path = '/content/gdrive/My Drive/ml_project'

# Save train dataset to pickle file
train_data_path = directory_path + 'train.pkl'
train_data = {'train_images': train_images, 'train_labels': train_labels}
with open(train_data_path, 'wb') as f:
    pickle.dump(train_data, f)

# Save test dataset to pickle file
test_data_path = directory_path + 'test.pkl'
test_data = {'test_images': test_images, 'test_labels': test_labels}
with open(test_data_path, 'wb') as f:
    pickle.dump(test_data, f)

# %% [markdown]
# # Loading the Preprocessed Data

# %%
import pickle

# Directory of the dataset
directory_path = '/content/gdrive/My Drive/ml project/'

# Load train dataset from pickle file
train_data_path = directory_path + 'ml_projecttrain.pkl'
with open(train_data_path, 'rb') as f:
    train_data = pickle.load(f)
train_images_loaded = train_data['train_images']
train_labels_loaded = train_data['train_labels']

# Load test dataset from pickle file
test_data_path = directory_path + 'ml_projecttest.pkl'
with open(test_data_path, 'rb') as f:
    test_data = pickle.load(f)
test_images_loaded = test_data['test_images']
test_labels_loaded = test_data['test_labels']

# %%
print("Train images shape:", train_images_loaded.shape)
print("Train labels shape:", train_labels_loaded.shape)
print("Test images shape:", test_images_loaded.shape)
print("Test labels shape:", test_labels_loaded.shape)
# Out:
# Train images shape: (4733, 64, 64, 3)
# Train labels shape: (4733,)
# Test images shape: (1184, 64, 64, 3)
# Test labels shape: (1184,)

# %%
train_images_loaded.max()
# Out:
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the number of images to plot
num_images_to_plot = 4

# Generate random indices for images
random_indices = np.random.choice(len(train_images_loaded), num_images_to_plot, replace=False)

# Plot the randomly selected images
plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(1, num_images_to_plot, i + 1)
    plt.imshow(train_images_loaded[idx])  # Assuming train_images_loaded contains the loaded images
    plt.title(f"Label: {train_labels_loaded[idx]}")
    plt.axis('off')

plt.show()

# %% [markdown]
# # AlexNet

# %%
from tensorflow.keras import layers, models

def Alexnet_model(input_shape, num_classes=1):
    model = models.Sequential([
        layers.Conv2D(96, (11, 11), strides=4, padding='same', activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D((3, 3), strides=2),
        layers.Conv2D(256, (5, 5), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((3, 3), strides=2),
        layers.Conv2D(384, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(384, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((3, 3), strides=2),
        layers.Flatten(),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='sigmoid')
    ])
    return model

# %% [markdown]
# # ResNet

# %%
from tensorflow.keras import layers, models

def identity_block(input_tensor, filters, kernel_size=3):
    x = layers.Conv2D(filters, kernel_size, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def conv_block(input_tensor, filters, kernel_size=3, strides=2):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    shortcut = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def ResNet_model(input_shape=(64, 64, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = conv_block(x, 64, strides=1)
    x = identity_block(x, 64)
    x = identity_block(x, 64)

    x = conv_block(x, 128)
    x = identity_block(x, 128)
    x = identity_block(x, 128)

    x = conv_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)

    x = conv_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    return model

# %% [markdown]
# # VGG16

# %%
from tensorflow.keras import layers, models

def VGG16_model(input_shape, num_classes=1):
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 2
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 3
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 4
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 5
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Fully connected layers
    model.add(layers.Flatten())
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='sigmoid'))  # Use sigmoid for binary classification

    return model

# %% [markdown]
# # Training

# %%
def save_model_keras(model, name, root_path='/content/gdrive/My Drive/ml project'):
    file_path = root_path + f'models/{name}.h5'
    model.save(file_path)
    print(f" Model {name} has been saved. ")

def load_model_keras(name, root_path='/content/gdrive/My Drive/ml project'):
    file_path = root_path + f'models/{name}.h5'
    model = tf.keras.models.load_model(file_path)
    model.summary()
    print(f" Model {name} has been saved. ")
    return model

# %%
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import KFold

def train_loop_optimized(model, optimizer, x_train, y_train, batch_size, num_epochs, k_fold=5):
    kf = KFold(n_splits=k_fold, shuffle=True, random_state=42)
    all_val_losses = []
    all_val_accuracies = []
    all_zero_one_losses = []

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    for fold, (train_index, val_index) in enumerate(kf.split(x_train), 1):
        print(f'==== Training Fold {fold} ====')
        X_train, X_val = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        # Early stopping callback
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        history = model.fit(
            X_train, y_train_fold,
            validation_data=(X_val, y_val_fold),
            epochs=num_epochs,
            batch_size=batch_size,
            callbacks=[early_stopping],
            verbose=1
        )

        val_loss = history.history['val_loss']
        val_accuracy = history.history['val_accuracy']
        zero_one_loss = [1 - acc for acc in val_accuracy]

        best_epoch = np.argmin(val_loss)
        print(f'Best epoch for Fold {fold}: {best_epoch + 1}, Validation Loss: {val_loss[best_epoch]:.4f}, Validation Accuracy: {val_accuracy[best_epoch]:.4f}, Zero-One Loss: {zero_one_loss[best_epoch]:.4f}')

        all_val_losses.append(val_loss)
        all_val_accuracies.append(val_accuracy)
        all_zero_one_losses.append(zero_one_loss)

    df_val_losses = pd.DataFrame(all_val_losses).T
    df_val_accuracies = pd.DataFrame(all_val_accuracies).T
    df_zero_one_losses = pd.DataFrame(all_zero_one_losses).T

    return model, df_val_losses, df_val_accuracies, df_zero_one_losses

# %%
df_val_losses
# Out:
#            0         1         2         3         4
# 0   0.690202  0.295323  0.284932  0.159615  0.276751
# 1   0.688697  0.336257  0.298575  0.211840  0.234866
# 2   0.688406  0.306186  0.291665  0.154995  0.205956
# 3   0.688308  0.303339  0.340113  0.261072  0.215099
# 4   0.688023  0.274840  0.311888  0.168671  0.252022
# 5   0.687771  0.280017  0.272832  0.155677  0.238676
# 6   0.687304  0.279726  0.313089  0.158881  0.229434
# 7   0.686389  0.279774  0.281547  0.190191  0.206706
# 8   0.685218  0.366502  0.244766       NaN       NaN
# 9   0.681842  0.283079  0.304953       NaN       NaN
# 10  0.674720       NaN  0.246962       NaN       NaN
# 11  0.662256       NaN  0.255828       NaN       NaN
# 12  0.610175       NaN  0.241210       NaN       NaN
# 13  0.670460       NaN  0.253617       NaN       NaN
# 14  0.545134       NaN  0.245488       NaN       NaN
# 15  0.653775       NaN  0.234563       NaN       NaN
# 16  0.524253       NaN  0.289388       NaN       NaN
# 17  0.540046       NaN  0.372038       NaN       NaN
# 18  0.449145       NaN  0.214452       NaN       NaN
# 19  0.483314       NaN  0.247242       NaN       NaN
# 20  0.408045       NaN  0.251358       NaN       NaN
# 21  0.392588       NaN  0.247991       NaN       NaN
# 22  0.397758       NaN  0.230315       NaN       NaN
# 23  0.409771       NaN  0.273859       NaN       NaN
# 24  0.527880       NaN       NaN       NaN       NaN
# 25  0.367443       NaN       NaN       NaN       NaN
# 26  0.481893       NaN       NaN       NaN       NaN
# 27  0.360732       NaN       NaN       NaN       NaN
# 28  0.373580       NaN       NaN       NaN       NaN
# 29  0.375369       NaN       NaN       NaN       NaN

# %%
df_val_accuracies
# Out:
#            0         1         2         3         4
# 0   0.549102  0.884900  0.881732  0.942918  0.886892
# 1   0.549102  0.870116  0.882788  0.920719  0.909091
# 2   0.549102  0.883844  0.881732  0.946089  0.914376
# 3   0.549102  0.889124  0.855333  0.890063  0.909091
# 4   0.549102  0.895459  0.868004  0.937632  0.900634
# 5   0.549102  0.892291  0.890180  0.941860  0.906977
# 6   0.549102  0.895459  0.879620  0.943975  0.901691
# 7   0.549102  0.892291  0.877508  0.924947  0.917548
# 8   0.549102  0.857445  0.904963       NaN       NaN
# 9   0.549102  0.897571  0.878564       NaN       NaN
# 10  0.549102       NaN  0.889124       NaN       NaN
# 11  0.549102       NaN  0.895459       NaN       NaN
# 12  0.723337       NaN  0.895459       NaN       NaN
# 13  0.563886       NaN  0.890180       NaN       NaN
# 14  0.733896       NaN  0.893347       NaN       NaN
# 15  0.658923       NaN  0.911299       NaN       NaN
# 16  0.748680       NaN  0.888068       NaN       NaN
# 17  0.736008       NaN  0.838437       NaN       NaN
# 18  0.791975       NaN  0.910243       NaN       NaN
# 19  0.784583       NaN  0.897571       NaN       NaN
# 20  0.816262       NaN  0.891235       NaN       NaN
# 21  0.822598       NaN  0.899683       NaN       NaN
# 22  0.820486       NaN  0.902851       NaN       NaN
# 23  0.815206       NaN  0.888068       NaN       NaN
# 24  0.751848       NaN       NaN       NaN       NaN
# 25  0.838437       NaN       NaN       NaN       NaN
# 26  0.789863       NaN       NaN       NaN       NaN
# 27  0.842661       NaN       NaN       NaN       NaN
# 28  0.823654       NaN       NaN       NaN       NaN
# 29  0.839493       NaN       NaN       NaN       NaN

# %%
df_zero_one_losses
# Out:
#            0         1         2         3         4
# 0   0.450898  0.115100  0.118268  0.057082  0.113108
# 1   0.450898  0.129884  0.117212  0.079281  0.090909
# 2   0.450898  0.116156  0.118268  0.053911  0.085624
# 3   0.450898  0.110876  0.144667  0.109937  0.090909
# 4   0.450898  0.104541  0.131996  0.062368  0.099366
# 5   0.450898  0.107709  0.109820  0.058140  0.093023
# 6   0.450898  0.104541  0.120380  0.056025  0.098309
# 7   0.450898  0.107709  0.122492  0.075053  0.082452
# 8   0.450898  0.142555  0.095037       NaN       NaN
# 9   0.450898  0.102429  0.121436       NaN       NaN
# 10  0.450898       NaN  0.110876       NaN       NaN
# 11  0.450898       NaN  0.104541       NaN       NaN
# 12  0.276663       NaN  0.104541       NaN       NaN
# 13  0.436114       NaN  0.109820       NaN       NaN
# 14  0.266104       NaN  0.106653       NaN       NaN
# 15  0.341077       NaN  0.088701       NaN       NaN
# 16  0.251320       NaN  0.111932       NaN       NaN
# 17  0.263992       NaN  0.161563       NaN       NaN
# 18  0.208025       NaN  0.089757       NaN       NaN
# 19  0.215417       NaN  0.102429       NaN       NaN
# 20  0.183738       NaN  0.108765       NaN       NaN
# 21  0.177402       NaN  0.100317       NaN       NaN
# 22  0.179514       NaN  0.097149       NaN       NaN
# 23  0.184794       NaN  0.111932       NaN       NaN
# 24  0.248152       NaN       NaN       NaN       NaN
# 25  0.161563       NaN       NaN       NaN       NaN
# 26  0.210137       NaN       NaN       NaN       NaN
# 27  0.157339       NaN       NaN       NaN       NaN
# 28  0.176346       NaN       NaN       NaN       NaN
# 29  0.160507       NaN       NaN       NaN       NaN
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_zero_one_losses[0].plot(kind='hist', bins=20, title=0)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses[1].plot(kind='hist', bins=20, title=1)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses[2].plot(kind='hist', bins=20, title=2)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses[3].plot(kind='hist', bins=20, title=3)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_zero_one_losses.plot(kind='scatter', x=0, y=1, s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses.plot(kind='scatter', x=1, y=2, s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses.plot(kind='scatter', x=2, y=3, s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses.plot(kind='scatter', x=3, y=4, s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# df_zero_one_losses[0].plot(kind='line', figsize=(8, 4), title=0)
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses[1].plot(kind='line', figsize=(8, 4), title=1)
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses[2].plot(kind='line', figsize=(8, 4), title=2)
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# df_zero_one_losses[3].plot(kind='line', figsize=(8, 4), title=3)
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df_zero_one_losses[3].plot(kind='line', figsize=(8, 4), title=3)
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
df_zero_one_losses[2].plot(kind='line', figsize=(8, 4), title=2)
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
input_shape = (64, 64, 3)
num_epochs = 30
batch_size = 128
learning_rates = [0.005, 0.01, 0.1]
model_types = ["AlexNet", "ResNet", "VGG16"]


train_mode = True

for model_type in model_types:
    for learning_rate in learning_rates:
        if train_mode:
            if model_type == "AlexNet":
                model = Alexnet_model(input_shape)
            elif model_type == "VGG16":
                model = VGG16_model(input_shape)
            elif model_type == "ResNet":
                model = ResNet_model(input_shape)

            print(f"Creating the model for {model_type} and learning rate is {learning_rate}")

            optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

            trained_model, df_val_losses, df_val_accuracies, df_zero_one_losses = train_loop_optimized(
                model, optimizer, train_images_loaded, train_labels_loaded, batch_size, num_epochs
            )

            save_model_keras(trained_model, f'{model_type}_{learning_rate}')
# Out:
# Creating the model for VGG16 and learning rate is 0.005
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 27s 424ms/step - loss: 0.6920 - accuracy: 0.5370 - val_loss: 0.6902 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.6905 - accuracy: 0.5386 - val_loss: 0.6887 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6902 - accuracy: 0.5386 - val_loss: 0.6884 - val_accuracy: 0.5491
# Epoch 4/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6899 - accuracy: 0.5386 - val_loss: 0.6883 - val_accuracy: 0.5491
# Epoch 5/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.6899 - accuracy: 0.5386 - val_loss: 0.6880 - val_accuracy: 0.5491
# Epoch 6/30
# 30/30 [==============================] - 5s 157ms/step - loss: 0.6896 - accuracy: 0.5386 - val_loss: 0.6878 - val_accuracy: 0.5491
# Epoch 7/30
# 30/30 [==============================] - 5s 159ms/step - loss: 0.6892 - accuracy: 0.5386 - val_loss: 0.6873 - val_accuracy: 0.5491
# Epoch 8/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.6886 - accuracy: 0.5386 - val_loss: 0.6864 - val_accuracy: 0.5491
# Epoch 9/30
# 30/30 [==============================] - 5s 161ms/step - loss: 0.6879 - accuracy: 0.5386 - val_loss: 0.6852 - val_accuracy: 0.5491
# Epoch 10/30
# 30/30 [==============================] - 5s 161ms/step - loss: 0.6858 - accuracy: 0.5386 - val_loss: 0.6818 - val_accuracy: 0.5491
# Epoch 11/30
# 30/30 [==============================] - 5s 176ms/step - loss: 0.6818 - accuracy: 0.5386 - val_loss: 0.6747 - val_accuracy: 0.5491
# Epoch 12/30
# 30/30 [==============================] - 5s 164ms/step - loss: 0.6729 - accuracy: 0.5386 - val_loss: 0.6623 - val_accuracy: 0.5491
# Epoch 13/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.6492 - accuracy: 0.6083 - val_loss: 0.6102 - val_accuracy: 0.7233
# Epoch 14/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.6363 - accuracy: 0.6646 - val_loss: 0.6705 - val_accuracy: 0.5639
# Epoch 15/30
# 30/30 [==============================] - 5s 181ms/step - loss: 0.6091 - accuracy: 0.7060 - val_loss: 0.5451 - val_accuracy: 0.7339
# Epoch 16/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.5265 - accuracy: 0.7512 - val_loss: 0.6538 - val_accuracy: 0.6589
# Epoch 17/30
# 30/30 [==============================] - 5s 184ms/step - loss: 0.5524 - accuracy: 0.7272 - val_loss: 0.5243 - val_accuracy: 0.7487
# Epoch 18/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.5191 - accuracy: 0.7499 - val_loss: 0.5400 - val_accuracy: 0.7360
# Epoch 19/30
# 30/30 [==============================] - 5s 179ms/step - loss: 0.4723 - accuracy: 0.7810 - val_loss: 0.4491 - val_accuracy: 0.7920
# Epoch 20/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.4475 - accuracy: 0.8019 - val_loss: 0.4833 - val_accuracy: 0.7846
# Epoch 21/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.4288 - accuracy: 0.8104 - val_loss: 0.4080 - val_accuracy: 0.8163
# Epoch 22/30
# 30/30 [==============================] - 5s 184ms/step - loss: 0.4105 - accuracy: 0.8278 - val_loss: 0.3926 - val_accuracy: 0.8226
# Epoch 23/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.4393 - accuracy: 0.8022 - val_loss: 0.3978 - val_accuracy: 0.8205
# Epoch 24/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.4220 - accuracy: 0.8125 - val_loss: 0.4098 - val_accuracy: 0.8152
# Epoch 25/30
# 30/30 [==============================] - 5s 165ms/step - loss: 0.4360 - accuracy: 0.8006 - val_loss: 0.5279 - val_accuracy: 0.7518
# Epoch 26/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.4014 - accuracy: 0.8214 - val_loss: 0.3674 - val_accuracy: 0.8384
# Epoch 27/30
# 30/30 [==============================] - 5s 176ms/step - loss: 0.3606 - accuracy: 0.8450 - val_loss: 0.4819 - val_accuracy: 0.7899
# Epoch 28/30
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3767 - accuracy: 0.8405 - val_loss: 0.3607 - val_accuracy: 0.8427
# Epoch 29/30
# 30/30 [==============================] - 5s 166ms/step - loss: 0.3652 - accuracy: 0.8428 - val_loss: 0.3736 - val_accuracy: 0.8237
# Epoch 30/30
# 30/30 [==============================] - 5s 166ms/step - loss: 0.3830 - accuracy: 0.8373 - val_loss: 0.3754 - val_accuracy: 0.8395
# Best epoch for Fold 1: 28, Validation Loss: 0.3607, Validation Accuracy: 0.8427, Zero-One Loss: 0.1573
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 181ms/step - loss: 0.3481 - accuracy: 0.8566 - val_loss: 0.2953 - val_accuracy: 0.8849
# Epoch 2/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.3155 - accuracy: 0.8703 - val_loss: 0.3363 - val_accuracy: 0.8701
# Epoch 3/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.3159 - accuracy: 0.8698 - val_loss: 0.3062 - val_accuracy: 0.8838
# Epoch 4/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2973 - accuracy: 0.8825 - val_loss: 0.3033 - val_accuracy: 0.8891
# Epoch 5/30
# 30/30 [==============================] - 6s 187ms/step - loss: 0.2985 - accuracy: 0.8798 - val_loss: 0.2748 - val_accuracy: 0.8955
# Epoch 6/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.2844 - accuracy: 0.8854 - val_loss: 0.2800 - val_accuracy: 0.8923
# Epoch 7/30
# 30/30 [==============================] - 5s 180ms/step - loss: 0.2946 - accuracy: 0.8801 - val_loss: 0.2797 - val_accuracy: 0.8955
# Epoch 8/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2870 - accuracy: 0.8880 - val_loss: 0.2798 - val_accuracy: 0.8923
# Epoch 9/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2788 - accuracy: 0.8803 - val_loss: 0.3665 - val_accuracy: 0.8574
# Epoch 10/30
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3036 - accuracy: 0.8698 - val_loss: 0.2831 - val_accuracy: 0.8976
# Best epoch for Fold 2: 5, Validation Loss: 0.2748, Validation Accuracy: 0.8955, Zero-One Loss: 0.1045
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 6s 192ms/step - loss: 0.3019 - accuracy: 0.8767 - val_loss: 0.2849 - val_accuracy: 0.8817
# Epoch 2/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.3105 - accuracy: 0.8730 - val_loss: 0.2986 - val_accuracy: 0.8828
# Epoch 3/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.2914 - accuracy: 0.8798 - val_loss: 0.2917 - val_accuracy: 0.8817
# Epoch 4/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.2778 - accuracy: 0.8901 - val_loss: 0.3401 - val_accuracy: 0.8553
# Epoch 5/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2754 - accuracy: 0.8893 - val_loss: 0.3119 - val_accuracy: 0.8680
# Epoch 6/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2750 - accuracy: 0.8864 - val_loss: 0.2728 - val_accuracy: 0.8902
# Epoch 7/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2627 - accuracy: 0.8893 - val_loss: 0.3131 - val_accuracy: 0.8796
# Epoch 8/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.2534 - accuracy: 0.9039 - val_loss: 0.2815 - val_accuracy: 0.8775
# Epoch 9/30
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2502 - accuracy: 0.8973 - val_loss: 0.2448 - val_accuracy: 0.9050
# Epoch 10/30
# 30/30 [==============================] - 5s 180ms/step - loss: 0.2683 - accuracy: 0.8925 - val_loss: 0.3050 - val_accuracy: 0.8786
# Epoch 11/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.2538 - accuracy: 0.8920 - val_loss: 0.2470 - val_accuracy: 0.8891
# Epoch 12/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2361 - accuracy: 0.9060 - val_loss: 0.2558 - val_accuracy: 0.8955
# Epoch 13/30
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2579 - accuracy: 0.8973 - val_loss: 0.2412 - val_accuracy: 0.8955
# Epoch 14/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2421 - accuracy: 0.9007 - val_loss: 0.2536 - val_accuracy: 0.8902
# Epoch 15/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.2623 - accuracy: 0.8925 - val_loss: 0.2455 - val_accuracy: 0.8933
# Epoch 16/30
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2108 - accuracy: 0.9152 - val_loss: 0.2346 - val_accuracy: 0.9113
# Epoch 17/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.2107 - accuracy: 0.9147 - val_loss: 0.2894 - val_accuracy: 0.8881
# Epoch 18/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.2320 - accuracy: 0.9118 - val_loss: 0.3720 - val_accuracy: 0.8384
# Epoch 19/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2070 - accuracy: 0.9189 - val_loss: 0.2145 - val_accuracy: 0.9102
# Epoch 20/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2000 - accuracy: 0.9192 - val_loss: 0.2472 - val_accuracy: 0.8976
# Epoch 21/30
# 30/30 [==============================] - 5s 180ms/step - loss: 0.2371 - accuracy: 0.9012 - val_loss: 0.2514 - val_accuracy: 0.8912
# Epoch 22/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.2371 - accuracy: 0.8999 - val_loss: 0.2480 - val_accuracy: 0.8997
# Epoch 23/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.2311 - accuracy: 0.9044 - val_loss: 0.2303 - val_accuracy: 0.9029
# Epoch 24/30
# 30/30 [==============================] - 5s 175ms/step - loss: 0.1984 - accuracy: 0.9202 - val_loss: 0.2739 - val_accuracy: 0.8881
# Best epoch for Fold 3: 19, Validation Loss: 0.2145, Validation Accuracy: 0.9102, Zero-One Loss: 0.0898
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 13s 454ms/step - loss: 0.2193 - accuracy: 0.9115 - val_loss: 0.1596 - val_accuracy: 0.9429
# Epoch 2/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2358 - accuracy: 0.9031 - val_loss: 0.2118 - val_accuracy: 0.9207
# Epoch 3/30
# 30/30 [==============================] - 5s 175ms/step - loss: 0.2359 - accuracy: 0.9060 - val_loss: 0.1550 - val_accuracy: 0.9461
# Epoch 4/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2190 - accuracy: 0.9129 - val_loss: 0.2611 - val_accuracy: 0.8901
# Epoch 5/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.2167 - accuracy: 0.9092 - val_loss: 0.1687 - val_accuracy: 0.9376
# Epoch 6/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.2010 - accuracy: 0.9213 - val_loss: 0.1557 - val_accuracy: 0.9419
# Epoch 7/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.1951 - accuracy: 0.9229 - val_loss: 0.1589 - val_accuracy: 0.9440
# Epoch 8/30
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2520 - accuracy: 0.9010 - val_loss: 0.1902 - val_accuracy: 0.9249
# Best epoch for Fold 4: 3, Validation Loss: 0.1550, Validation Accuracy: 0.9461, Zero-One Loss: 0.0539
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 179ms/step - loss: 0.2276 - accuracy: 0.9118 - val_loss: 0.2768 - val_accuracy: 0.8869
# Epoch 2/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2062 - accuracy: 0.9176 - val_loss: 0.2349 - val_accuracy: 0.9091
# Epoch 3/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.1821 - accuracy: 0.9276 - val_loss: 0.2060 - val_accuracy: 0.9144
# Epoch 4/30
# 30/30 [==============================] - 5s 182ms/step - loss: 0.1764 - accuracy: 0.9321 - val_loss: 0.2151 - val_accuracy: 0.9091
# Epoch 5/30
# 30/30 [==============================] - 5s 183ms/step - loss: 0.2000 - accuracy: 0.9203 - val_loss: 0.2520 - val_accuracy: 0.9006
# Epoch 6/30
# 30/30 [==============================] - 6s 186ms/step - loss: 0.1774 - accuracy: 0.9313 - val_loss: 0.2387 - val_accuracy: 0.9070
# Epoch 7/30
# 30/30 [==============================] - 5s 175ms/step - loss: 0.1967 - accuracy: 0.9245 - val_loss: 0.2294 - val_accuracy: 0.9017
# Epoch 8/30
# 30/30 [==============================] - 5s 178ms/step - loss: 0.1737 - accuracy: 0.9350 - val_loss: 0.2067 - val_accuracy: 0.9175
# Best epoch for Fold 5: 3, Validation Loss: 0.2060, Validation Accuracy: 0.9144, Zero-One Loss: 0.0856
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model VGG16_0.005 has been saved.

# %%
def load_model_keras(name, root_path='/content/gdrive/My Drive/ml project/'):
    file_path = os.path.join(root_path, f'{name}.h5')
    model = tf.keras.models.load_model(file_path)
    model.summary()
    print(f"Model {name} has been loaded.")
    return model

# %% [markdown]
# # Testing

# %%
def test_loop_optimized(model, x_test, y_test):
    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    zero_one_loss = 1 - accuracy

    print(f'Test Accuracy: {accuracy:.4f}, Zero-One Loss: {zero_one_loss:.4f}')

    y_preds = model.predict(x_test)
    y_preds = np.round(y_preds).astype(int)

    return y_preds

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt




def plot_and_display_confusion_matrix(cm, classes, normalize=False, title='', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

def generate_and_display_confusion_matrix(predictions, true_labels, plot=False):
    classes = [0, 1]
    cm = confusion_matrix(true_labels, predictions, labels=classes)
    if plot:
        plot_and_display_confusion_matrix(cm, classes=classes, normalize=False, title='Confusion Matrix')
    return cm

# %%
# Load the trained model
model = load_model_keras('VGG16_0.005')

# Perform testing
y_preds = test_loop_optimized(model, test_images_loaded, test_labels_loaded)

# Generate and display confusion matrix
generate_and_display_confusion_matrix(y_preds, test_labels_loaded, plot=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_13 (Conv2D)          (None, 64, 64, 64)        1792
#
#  conv2d_14 (Conv2D)          (None, 64, 64, 64)        36928
#
#  max_pooling2d_5 (MaxPoolin  (None, 32, 32, 64)        0
#  g2D)
#
#  conv2d_15 (Conv2D)          (None, 32, 32, 128)       73856
#
#  conv2d_16 (Conv2D)          (None, 32, 32, 128)       147584
#
#  max_pooling2d_6 (MaxPoolin  (None, 16, 16, 128)       0
#  g2D)
#
#  conv2d_17 (Conv2D)          (None, 16, 16, 256)       295168
#
#  conv2d_18 (Conv2D)          (None, 16, 16, 256)       590080
#
#  conv2d_19 (Conv2D)          (None, 16, 16, 256)       590080
#
#  max_pooling2d_7 (MaxPoolin  (None, 8, 8, 256)         0
#  g2D)
#
#  conv2d_20 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_21 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  conv2d_22 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  max_pooling2d_8 (MaxPoolin  (None, 4, 4, 512)         0
#  g2D)
#
#  conv2d_23 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  conv2d_24 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  conv2d_25 (Conv2D)          (None, 4, 4, 512)         2359808
#
#  max_pooling2d_9 (MaxPoolin  (None, 2, 2, 512)         0
#  g2D)
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_3 (Dense)             (None, 4096)              8392704
#
#  dropout_2 (Dropout)         (None, 4096)              0
#
#  dense_4 (Dense)             (None, 4096)              16781312
#
#  dropout_3 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 39892801 (152.18 MB)
# Trainable params: 39892801 (152.18 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# Model VGG16_0.005 has been loaded.
# Test Accuracy: 0.9062, Zero-One Loss: 0.0938
# 37/37 [==============================] - 1s 14ms/step
# Confusion matrix, without normalization
# array([[589,  51],
#        [ 60, 484]])
