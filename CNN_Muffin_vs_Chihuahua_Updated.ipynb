# %%
from google.colab import drive
drive.mount('/content/gdrive',force_remount=True)
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# # Importing the Libraries

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.utils import image_dataset_from_directory

# %% [markdown]
# # Sample Image Visualizaiton

# %%
sample_image_path = '/content/gdrive/My Drive/ml project/muffin vs chihahua/train/chihuahua/img_0_198.jpg'

# Load the original image in RGB
original_image_rgb = cv2.imread(sample_image_path, cv2.IMREAD_COLOR)

# Resize the RGB image to 64x64 pixels
resized_rgb_64x64 = cv2.resize(original_image_rgb, (64, 64))

# Plot the images
plt.figure(figsize=(8, 4))

plt.subplot(1, 2, 1)
plt.imshow(cv2.cvtColor(original_image_rgb, cv2.COLOR_BGR2RGB))
plt.title('Original RGB Image')
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(cv2.cvtColor(resized_rgb_64x64, cv2.COLOR_BGR2RGB))
plt.title('Resized RGB Image (64x64)')
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Loading the Dataset

# %%
# Define directories for train and test data
train_dir = '/content/gdrive/My Drive/ml project/muffin vs chihahua/train'
test_dir = '/content/gdrive/My Drive/ml project/muffin vs chihahua/test'

# Define image size
image_size = (64, 64)

# Load train and test datasets
train_dataset = image_dataset_from_directory(
    train_dir,
    image_size=image_size,
    batch_size=1,
    shuffle=True)

test_dataset = image_dataset_from_directory(
    test_dir,
    image_size=image_size,
    batch_size=1,
    shuffle=False)  # No need to shuffle test data

# Print class names
class_names = train_dataset.class_names
print("Class names:", class_names)
# Out:
# Found 4733 files belonging to 2 classes.
# Found 1184 files belonging to 2 classes.
# Class names: ['chihuahua', 'muffin']

# %% [markdown]
# # Splitting

# %%
# Extract images and labels from training data
train_images = []
train_labels = []
for images, labels in train_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE):
    train_images.extend(images.numpy())
    train_labels.extend(labels.numpy())

# Extract images and labels from test data
test_images = []
test_labels = []
for images, labels in test_dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE):
    test_images.extend(images.numpy())
    test_labels.extend(labels.numpy())

# Convert lists to NumPy arrays
train_images = np.array(train_images)
train_labels = np.array(train_labels)
test_images = np.array(test_images)
test_labels = np.array(test_labels)

# %% [markdown]
# # Data Normalization

# %%
train_images = train_images / 255.0
test_images = test_images / 255.0

print("Shape of train_images:", train_images.shape)
print("Shape of train_labels:", train_labels.shape)
print("Shape of test_images:", test_images.shape)
print("Shape of test_labels:", test_labels.shape)
# Out:
# Shape of train_images: (4733, 64, 64, 3)
# Shape of train_labels: (4733,)
# Shape of test_images: (1184, 64, 64, 3)
# Shape of test_labels: (1184,)

# %%
print(train_images.min())
print(train_images.max())
# Out:
# 0.0
# 1.0

# %%
import random
import matplotlib.pyplot as plt

# Define the number of images to plot
num_images = 4

# Randomly select indices for the images
random_indices = random.sample(range(len(train_images)), num_images)

# Plot the images
plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(1, num_images, i+1)
    plt.imshow(train_images[idx])

    # Labeling
    numerical_label = train_labels[idx]
    if numerical_label == 1:
        label_name = "Muffin"
    else:
        label_name = "Chihuahua"

    plt.title("Label: {} ({})".format(label_name, numerical_label))
    plt.axis("off")

plt.show()

# %%
train_images[0]
# Out:
# array([[[0.8392157 , 0.85882354, 0.87058824],
#         [0.8392157 , 0.85882354, 0.87058824],
#         [0.8392157 , 0.85882354, 0.88039213],
#         ...,
#         [0.9352941 , 0.95392156, 0.96568626],
#         [0.88308823, 0.9232843 , 0.9311274 ],
#         [0.83504903, 0.8892157 , 0.9007353 ]],
#
#        [[0.8392157 , 0.85490197, 0.85882354],
#         [0.8392157 , 0.85490197, 0.8666667 ],
#         [0.8392157 , 0.8509804 , 0.87058824],
#         ...,
#         [0.9580882 , 0.9737745 , 0.97769606],
#         [0.96838236, 0.99264705, 1.        ],
#         [0.9497549 , 0.98995095, 0.9941176 ]],
#
#        [[0.84289217, 0.8507353 , 0.84681374],
#         [0.85294116, 0.8568627 , 0.86470586],
#         [0.85882354, 0.8627451 , 0.8784314 ],
#         ...,
#         [0.9647059 , 0.9703431 , 0.96862745],
#         [0.97156864, 0.9872549 , 0.9911765 ],
#         [0.96887255, 0.9852941 , 0.9970588 ]],
#
#        ...,
#
#        [[0.7490196 , 0.8490196 , 0.84607846],
#         [0.7519608 , 0.84607846, 0.84607846],
#         [0.7593137 , 0.8377451 , 0.84166664],
#         ...,
#         [0.22058824, 0.22156863, 0.22941177],
#         [0.11960784, 0.12352941, 0.12181372],
#         [0.5115196 , 0.53210783, 0.51642156]],
#
#        [[0.7735294 , 0.85588235, 0.8598039 ],
#         [0.7735294 , 0.85588235, 0.8598039 ],
#         [0.76911765, 0.8514706 , 0.85539216],
#         ...,
#         [0.09558824, 0.1002451 , 0.10784314],
#         [0.18333334, 0.18333334, 0.18333334],
#         [0.12794118, 0.13431373, 0.12328431]],
#
#        [[0.7911765 , 0.86960787, 0.87352943],
#         [0.7911765 , 0.86960787, 0.87352943],
#         [0.76691175, 0.8492647 , 0.85318625],
#         ...,
#         [0.1254902 , 0.14313726, 0.14607844],
#         [0.10980392, 0.11617647, 0.11299019],
#         [0.1497549 , 0.16862746, 0.15318628]]], dtype=float32)

# %%
print(train_images.shape)
print(train_labels.shape)
print(test_images.shape)
print(test_labels.shape)
# Out:
# (4733, 64, 64, 3)
# (4733,)
# (1184, 64, 64, 3)
# (1184,)

# %% [markdown]
# # Saving the Preprocessed Data

# %%
import pickle

# Specifying the directory
directory_path = '/content/gdrive/My Drive/ml_project'

# Save train dataset to pickle file
train_data_path = directory_path + 'train.pkl'
train_data = {'train_images': train_images, 'train_labels': train_labels}
with open(train_data_path, 'wb') as f:
    pickle.dump(train_data, f)

# Save test dataset to pickle file
test_data_path = directory_path + 'test.pkl'
test_data = {'test_images': test_images, 'test_labels': test_labels}
with open(test_data_path, 'wb') as f:
    pickle.dump(test_data, f)

# %% [markdown]
# # Loading the Preprocessed Data

# %%
import pickle

# Directory of the dataset
directory_path = '/content/gdrive/My Drive/ml project/'

# Load train dataset from pickle file
train_data_path = directory_path + 'ml_projecttrain.pkl'
with open(train_data_path, 'rb') as f:
    train_data = pickle.load(f)
train_images_loaded = train_data['train_images']
train_labels_loaded = train_data['train_labels']

# Load test dataset from pickle file
test_data_path = directory_path + 'ml_projecttest.pkl'
with open(test_data_path, 'rb') as f:
    test_data = pickle.load(f)
test_images_loaded = test_data['test_images']
test_labels_loaded = test_data['test_labels']

# %%
print("Train images shape:", train_images_loaded.shape)
print("Train labels shape:", train_labels_loaded.shape)
print("Test images shape:", test_images_loaded.shape)
print("Test labels shape:", test_labels_loaded.shape)
# Out:
# Train images shape: (4733, 64, 64, 3)
# Train labels shape: (4733,)
# Test images shape: (1184, 64, 64, 3)
# Test labels shape: (1184,)

# %%
train_images_loaded.max()
# Out:
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the number of images to plot
num_images_to_plot = 4

# Generate random indices for images
random_indices = np.random.choice(len(train_images_loaded), num_images_to_plot, replace=False)

# Plot the randomly selected images
plt.figure(figsize=(10, 10))
for i, idx in enumerate(random_indices):
    plt.subplot(1, num_images_to_plot, i + 1)
    plt.imshow(train_images_loaded[idx])  # Assuming train_images_loaded contains the loaded images
    plt.title(f"Label: {train_labels_loaded[idx]}")
    plt.axis('off')

plt.show()

# %% [markdown]
# # AlexNet

# %%
from tensorflow.keras import layers, models

def Alexnet_model(input_shape, num_classes=1):
    model = models.Sequential([
        layers.Conv2D(96, (11, 11), strides=4, padding='same', activation='relu', input_shape=input_shape),
        layers.BatchNormalization(),
        layers.MaxPooling2D((3, 3), strides=2),
        layers.Conv2D(256, (5, 5), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((3, 3), strides=2),
        layers.Conv2D(384, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(384, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((3, 3), strides=2),
        layers.Flatten(),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(4096, activation='relu'),
        layers.Dropout(0.5),
        layers.Dense(num_classes, activation='sigmoid')
    ])
    return model

# %% [markdown]
# # ResNet

# %%
from tensorflow.keras import layers, models

def identity_block(input_tensor, filters, kernel_size=3):
    x = layers.Conv2D(filters, kernel_size, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    x = layers.add([x, input_tensor])
    x = layers.Activation('relu')(x)
    return x

def conv_block(input_tensor, filters, kernel_size=3, strides=2):
    x = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)

    x = layers.Conv2D(filters, kernel_size, padding='same')(x)
    x = layers.BatchNormalization()(x)

    shortcut = layers.Conv2D(filters, kernel_size, strides=strides, padding='same')(input_tensor)
    shortcut = layers.BatchNormalization()(shortcut)

    x = layers.add([x, shortcut])
    x = layers.Activation('relu')(x)
    return x

def ResNet_model(input_shape=(64, 64, 3), num_classes=1):
    inputs = layers.Input(shape=input_shape)
    x = layers.Conv2D(64, (7, 7), strides=(2, 2), padding='same')(inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.MaxPooling2D((3, 3), strides=(2, 2), padding='same')(x)

    x = conv_block(x, 64, strides=1)
    x = identity_block(x, 64)
    x = identity_block(x, 64)

    x = conv_block(x, 128)
    x = identity_block(x, 128)
    x = identity_block(x, 128)

    x = conv_block(x, 256)
    x = identity_block(x, 256)
    x = identity_block(x, 256)

    x = conv_block(x, 512)
    x = identity_block(x, 512)
    x = identity_block(x, 512)

    x = layers.GlobalAveragePooling2D()(x)
    x = layers.Dense(512, activation='relu')(x)
    x = layers.Dropout(0.5)(x)
    outputs = layers.Dense(num_classes, activation='sigmoid')(x)

    model = models.Model(inputs, outputs)
    return model

# %% [markdown]
# # VGG16

# %%
from tensorflow.keras import layers, models

def VGG16_model(input_shape, num_classes=1):
    model = models.Sequential()

    # Block 1
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu', input_shape=input_shape))
    model.add(layers.Conv2D(64, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 2
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(128, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 3
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(256, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 4
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Block 5
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.Conv2D(512, (3, 3), padding='same', activation='relu'))
    model.add(layers.MaxPooling2D((2, 2), strides=(2, 2)))

    # Fully connected layers
    model.add(layers.Flatten())
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(4096, activation='relu'))
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(num_classes, activation='sigmoid'))  # Use sigmoid for binary classification

    return model

# %% [markdown]
# # Training

# %%
def save_model_keras(model, name, root_path='/content/gdrive/My Drive/ml project'):
    file_path = root_path + f'/{name}.h5'
    model.save(file_path)
    print(f" Model {name} has been saved. ")

def load_model_keras(name, root_path='/content/gdrive/My Drive/ml project'):
    file_path = root_path + f'/{name}.h5'
    model = tf.keras.models.load_model(file_path)
    model.summary()
    print(f" Model {name} has been saved. ")
    return model

# %%
from sklearn.model_selection import KFold
from tensorflow.keras.callbacks import EarlyStopping

def train_loop_optimized(model, optimizer, x_train, y_train, batch_size, num_epochs, k_fold=5):
    kf = KFold(n_splits=k_fold, shuffle=True, random_state=42)
    all_val_losses = []
    all_val_accuracies = []
    all_zero_one_losses = []

    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['accuracy'])

    for fold, (train_index, val_index) in enumerate(kf.split(x_train), 1):
        print(f'==== Training Fold {fold} ====')
        X_train, X_val = x_train[train_index], x_train[val_index]
        y_train_fold, y_val_fold = y_train[train_index], y_train[val_index]

        # Early stopping callback
        early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

        history = model.fit(
            X_train, y_train_fold,
            validation_data=(X_val, y_val_fold),
            epochs=num_epochs,
            batch_size=batch_size,
            callbacks=[early_stopping],
            verbose=1
        )

        val_loss = history.history['val_loss']
        val_accuracy = history.history['val_accuracy']
        zero_one_loss = [1 - acc for acc in val_accuracy]

        best_epoch = np.argmin(val_loss)
        print(f'Best epoch for Fold {fold}: {best_epoch + 1}, Validation Loss: {val_loss[best_epoch]:.4f}, Validation Accuracy: {val_accuracy[best_epoch]:.4f}, Zero-One Loss: {zero_one_loss[best_epoch]:.4f}')

        all_val_losses.append(val_loss)
        all_val_accuracies.append(val_accuracy)
        all_zero_one_losses.append(zero_one_loss)

    df_val_losses = pd.DataFrame(all_val_losses).T
    df_val_accuracies = pd.DataFrame(all_val_accuracies).T
    df_zero_one_losses = pd.DataFrame(all_zero_one_losses).T

    return model, df_val_losses, df_val_accuracies, df_zero_one_losses

# %%
from sklearn.model_selection import KFold


input_shape = (64, 64, 3)
num_epochs = 30
batch_size = 128
learning_rates = [0.005, 0.01, 0.1]
model_types = ["AlexNet", "ResNet", "VGG16"]

train_mode = True

for model_type in model_types:
    for learning_rate in learning_rates:
        if train_mode:
            if model_type == "AlexNet":
                model = Alexnet_model(input_shape)
            elif model_type == "VGG16":
                model = VGG16_model(input_shape)
            elif model_type == "ResNet":
                model = ResNet_model(input_shape)

            print(f"Creating the model for {model_type} and learning rate is {learning_rate}")

            optimizer = tf.keras.optimizers.SGD(learning_rate=learning_rate, momentum=0.9)

            trained_model, df_val_losses, df_val_accuracies, df_zero_one_losses = train_loop_optimized(
                model, optimizer, train_images_loaded, train_labels_loaded, batch_size, num_epochs
            )

            save_model_keras(trained_model, f'{model_type}_{learning_rate}')
# Out:
# Creating the model for AlexNet and learning rate is 0.005
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 12s 98ms/step - loss: 0.5935 - accuracy: 0.6989 - val_loss: 0.6799 - val_accuracy: 0.5417
# Epoch 2/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.4803 - accuracy: 0.8030 - val_loss: 0.6701 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.3616 - accuracy: 0.8450 - val_loss: 0.6082 - val_accuracy: 0.6262
# Epoch 4/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.3126 - accuracy: 0.8767 - val_loss: 0.6051 - val_accuracy: 0.6294
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.2591 - accuracy: 0.8949 - val_loss: 0.6373 - val_accuracy: 0.6230
# Epoch 6/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.2331 - accuracy: 0.9031 - val_loss: 0.5803 - val_accuracy: 0.6336
# Epoch 7/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.2089 - accuracy: 0.9200 - val_loss: 1.5914 - val_accuracy: 0.5491
# Epoch 8/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.1748 - accuracy: 0.9334 - val_loss: 0.8767 - val_accuracy: 0.5755
# Epoch 9/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.1080 - accuracy: 0.9604 - val_loss: 1.3104 - val_accuracy: 0.5839
# Epoch 10/30
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1122 - accuracy: 0.9577 - val_loss: 0.5497 - val_accuracy: 0.7856
# Epoch 11/30
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0866 - accuracy: 0.9672 - val_loss: 0.5347 - val_accuracy: 0.8046
# Epoch 12/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0761 - accuracy: 0.9752 - val_loss: 1.4239 - val_accuracy: 0.6811
# Epoch 13/30
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0688 - accuracy: 0.9752 - val_loss: 0.4107 - val_accuracy: 0.8733
# Epoch 14/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0658 - accuracy: 0.9786 - val_loss: 0.6221 - val_accuracy: 0.8427
# Epoch 15/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0576 - accuracy: 0.9815 - val_loss: 1.0327 - val_accuracy: 0.7181
# Epoch 16/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0549 - accuracy: 0.9805 - val_loss: 1.0441 - val_accuracy: 0.7550
# Epoch 17/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0354 - accuracy: 0.9860 - val_loss: 0.5967 - val_accuracy: 0.8596
# Epoch 18/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0491 - accuracy: 0.9844 - val_loss: 1.0439 - val_accuracy: 0.7846
# Best epoch for Fold 1: 13, Validation Loss: 0.4107, Validation Accuracy: 0.8733, Zero-One Loss: 0.1267
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 39ms/step - loss: 0.1544 - accuracy: 0.9490 - val_loss: 1.4153 - val_accuracy: 0.5945
# Epoch 2/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1093 - accuracy: 0.9620 - val_loss: 0.1840 - val_accuracy: 0.9314
# Epoch 3/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0614 - accuracy: 0.9791 - val_loss: 0.4696 - val_accuracy: 0.8437
# Epoch 4/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0352 - accuracy: 0.9886 - val_loss: 1.1953 - val_accuracy: 0.7804
# Epoch 5/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0381 - accuracy: 0.9863 - val_loss: 0.4675 - val_accuracy: 0.8574
# Epoch 6/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0469 - accuracy: 0.9820 - val_loss: 2.2278 - val_accuracy: 0.6832
# Epoch 7/30
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0579 - accuracy: 0.9802 - val_loss: 0.5172 - val_accuracy: 0.8173
# Best epoch for Fold 2: 2, Validation Loss: 0.1840, Validation Accuracy: 0.9314, Zero-One Loss: 0.0686
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 2s 53ms/step - loss: 0.0695 - accuracy: 0.9757 - val_loss: 0.2120 - val_accuracy: 0.9197
# Epoch 2/30
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0423 - accuracy: 0.9839 - val_loss: 0.1747 - val_accuracy: 0.9303
# Epoch 3/30
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0390 - accuracy: 0.9852 - val_loss: 2.5958 - val_accuracy: 0.5956
# Epoch 4/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0404 - accuracy: 0.9863 - val_loss: 0.2381 - val_accuracy: 0.9293
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0423 - accuracy: 0.9842 - val_loss: 0.5991 - val_accuracy: 0.8141
# Epoch 6/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0396 - accuracy: 0.9857 - val_loss: 0.1456 - val_accuracy: 0.9546
# Epoch 7/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0271 - accuracy: 0.9913 - val_loss: 0.2104 - val_accuracy: 0.9303
# Epoch 8/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0264 - accuracy: 0.9921 - val_loss: 0.2624 - val_accuracy: 0.9356
# Epoch 9/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0137 - accuracy: 0.9966 - val_loss: 0.9268 - val_accuracy: 0.8046
# Epoch 10/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0213 - accuracy: 0.9945 - val_loss: 0.2339 - val_accuracy: 0.9271
# Epoch 11/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0273 - accuracy: 0.9910 - val_loss: 0.2615 - val_accuracy: 0.9197
# Best epoch for Fold 3: 6, Validation Loss: 0.1456, Validation Accuracy: 0.9546, Zero-One Loss: 0.0454
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 2s 84ms/step - loss: 0.0860 - accuracy: 0.9717 - val_loss: 1.2739 - val_accuracy: 0.6047
# Epoch 2/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0973 - accuracy: 0.9607 - val_loss: 0.1028 - val_accuracy: 0.9609
# Epoch 3/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0352 - accuracy: 0.9894 - val_loss: 0.3148 - val_accuracy: 0.8932
# Epoch 4/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0140 - accuracy: 0.9971 - val_loss: 0.0893 - val_accuracy: 0.9683
# Epoch 5/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0090 - accuracy: 0.9979 - val_loss: 0.1224 - val_accuracy: 0.9535
# Epoch 6/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0068 - accuracy: 0.9979 - val_loss: 0.5678 - val_accuracy: 0.8615
# Epoch 7/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0069 - accuracy: 0.9979 - val_loss: 0.2773 - val_accuracy: 0.9175
# Epoch 8/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0093 - accuracy: 0.9971 - val_loss: 1.1480 - val_accuracy: 0.7875
# Epoch 9/30
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0107 - accuracy: 0.9974 - val_loss: 0.9595 - val_accuracy: 0.7949
# Best epoch for Fold 4: 4, Validation Loss: 0.0893, Validation Accuracy: 0.9683, Zero-One Loss: 0.0317
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 41ms/step - loss: 0.0185 - accuracy: 0.9926 - val_loss: 0.2538 - val_accuracy: 0.9186
# Epoch 2/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0374 - accuracy: 0.9852 - val_loss: 0.6428 - val_accuracy: 0.8245
# Epoch 3/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0357 - accuracy: 0.9873 - val_loss: 0.7552 - val_accuracy: 0.8467
# Epoch 4/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0387 - accuracy: 0.9879 - val_loss: 0.3889 - val_accuracy: 0.8953
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0448 - accuracy: 0.9831 - val_loss: 0.1422 - val_accuracy: 0.9493
# Epoch 6/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0461 - accuracy: 0.9826 - val_loss: 0.7046 - val_accuracy: 0.8414
# Epoch 7/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0203 - accuracy: 0.9942 - val_loss: 0.1564 - val_accuracy: 0.9524
# Epoch 8/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0135 - accuracy: 0.9952 - val_loss: 0.0627 - val_accuracy: 0.9789
# Epoch 9/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.5744 - val_accuracy: 0.8393
# Epoch 10/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 1.8849 - val_accuracy: 0.6797
# Epoch 11/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0029 - accuracy: 0.9992 - val_loss: 0.0866 - val_accuracy: 0.9736
# Epoch 12/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0027 - accuracy: 0.9989 - val_loss: 0.4259 - val_accuracy: 0.9027
# Epoch 13/30
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0146 - accuracy: 0.9945 - val_loss: 0.1022 - val_accuracy: 0.9715
# Best epoch for Fold 5: 8, Validation Loss: 0.0627, Validation Accuracy: 0.9789, Zero-One Loss: 0.0211
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model AlexNet_0.005 has been saved.
# Creating the model for AlexNet and learning rate is 0.01
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 53ms/step - loss: 0.6635 - accuracy: 0.6867 - val_loss: 1.0315 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.4343 - accuracy: 0.8172 - val_loss: 1.3291 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.3579 - accuracy: 0.8545 - val_loss: 0.6901 - val_accuracy: 0.5565
# Epoch 4/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.3163 - accuracy: 0.8719 - val_loss: 0.6895 - val_accuracy: 0.5850
# Epoch 5/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.3044 - accuracy: 0.8814 - val_loss: 0.4974 - val_accuracy: 0.7360
# Epoch 6/30
# 30/30 [==============================] - 1s 36ms/step - loss: 0.2452 - accuracy: 0.9007 - val_loss: 0.4690 - val_accuracy: 0.7793
# Epoch 7/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.1905 - accuracy: 0.9287 - val_loss: 0.3921 - val_accuracy: 0.8321
# Epoch 8/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.1374 - accuracy: 0.9501 - val_loss: 0.5197 - val_accuracy: 0.7582
# Epoch 9/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.1751 - accuracy: 0.9313 - val_loss: 0.4341 - val_accuracy: 0.8237
# Epoch 10/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1193 - accuracy: 0.9527 - val_loss: 0.5505 - val_accuracy: 0.7962
# Epoch 11/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0846 - accuracy: 0.9699 - val_loss: 2.0012 - val_accuracy: 0.5787
# Epoch 12/30
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0819 - accuracy: 0.9704 - val_loss: 0.4874 - val_accuracy: 0.8384
# Best epoch for Fold 1: 7, Validation Loss: 0.3921, Validation Accuracy: 0.8321, Zero-One Loss: 0.1679
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1963 - accuracy: 0.9226 - val_loss: 0.7737 - val_accuracy: 0.6114
# Epoch 2/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.1662 - accuracy: 0.9348 - val_loss: 0.4312 - val_accuracy: 0.8237
# Epoch 3/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1290 - accuracy: 0.9490 - val_loss: 3.3320 - val_accuracy: 0.4900
# Epoch 4/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.1205 - accuracy: 0.9535 - val_loss: 2.0720 - val_accuracy: 0.5502
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0787 - accuracy: 0.9704 - val_loss: 0.6734 - val_accuracy: 0.7719
# Epoch 6/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.1358 - accuracy: 0.9488 - val_loss: 1.0272 - val_accuracy: 0.5966
# Epoch 7/30
# 30/30 [==============================] - 1s 35ms/step - loss: 0.1060 - accuracy: 0.9585 - val_loss: 0.8832 - val_accuracy: 0.6579
# Best epoch for Fold 2: 2, Validation Loss: 0.4312, Validation Accuracy: 0.8237, Zero-One Loss: 0.1763
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 49ms/step - loss: 0.1576 - accuracy: 0.9427 - val_loss: 0.4130 - val_accuracy: 0.8110
# Epoch 2/30
# 30/30 [==============================] - 1s 34ms/step - loss: 0.1643 - accuracy: 0.9329 - val_loss: 0.3212 - val_accuracy: 0.8617
# Epoch 3/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.1340 - accuracy: 0.9482 - val_loss: 1.5795 - val_accuracy: 0.6199
# Epoch 4/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0726 - accuracy: 0.9752 - val_loss: 0.4669 - val_accuracy: 0.8807
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0896 - accuracy: 0.9680 - val_loss: 0.6938 - val_accuracy: 0.7994
# Epoch 6/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0619 - accuracy: 0.9770 - val_loss: 3.2718 - val_accuracy: 0.5216
# Epoch 7/30
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0408 - accuracy: 0.9857 - val_loss: 2.0877 - val_accuracy: 0.6230
# Best epoch for Fold 3: 2, Validation Loss: 0.3212, Validation Accuracy: 0.8617, Zero-One Loss: 0.1383
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 40ms/step - loss: 0.1546 - accuracy: 0.9403 - val_loss: 0.3902 - val_accuracy: 0.8298
# Epoch 2/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.1327 - accuracy: 0.9490 - val_loss: 2.1355 - val_accuracy: 0.5846
# Epoch 3/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0904 - accuracy: 0.9654 - val_loss: 0.4750 - val_accuracy: 0.8277
# Epoch 4/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0696 - accuracy: 0.9723 - val_loss: 2.8856 - val_accuracy: 0.5825
# Epoch 5/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0566 - accuracy: 0.9791 - val_loss: 4.3332 - val_accuracy: 0.5539
# Epoch 6/30
# 30/30 [==============================] - 1s 36ms/step - loss: 0.0612 - accuracy: 0.9773 - val_loss: 0.2622 - val_accuracy: 0.9006
# Epoch 7/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0469 - accuracy: 0.9826 - val_loss: 2.2771 - val_accuracy: 0.6290
# Epoch 8/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0393 - accuracy: 0.9863 - val_loss: 0.4524 - val_accuracy: 0.8647
# Epoch 9/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0719 - accuracy: 0.9715 - val_loss: 2.6724 - val_accuracy: 0.5740
# Epoch 10/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0367 - accuracy: 0.9881 - val_loss: 0.6752 - val_accuracy: 0.8383
# Epoch 11/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0321 - accuracy: 0.9894 - val_loss: 0.2482 - val_accuracy: 0.9239
# Epoch 12/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0215 - accuracy: 0.9929 - val_loss: 0.2357 - val_accuracy: 0.9228
# Epoch 13/30
# 30/30 [==============================] - 1s 28ms/step - loss: 0.0211 - accuracy: 0.9926 - val_loss: 0.2628 - val_accuracy: 0.9260
# Epoch 14/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0173 - accuracy: 0.9931 - val_loss: 1.2582 - val_accuracy: 0.7252
# Epoch 15/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0099 - accuracy: 0.9963 - val_loss: 0.4740 - val_accuracy: 0.8943
# Epoch 16/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0106 - accuracy: 0.9974 - val_loss: 0.2921 - val_accuracy: 0.9228
# Epoch 17/30
# 30/30 [==============================] - 1s 34ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.3941 - val_accuracy: 0.9123
# Best epoch for Fold 4: 12, Validation Loss: 0.2357, Validation Accuracy: 0.9228, Zero-One Loss: 0.0772
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 40ms/step - loss: 0.0801 - accuracy: 0.9752 - val_loss: 1.7037 - val_accuracy: 0.6512
# Epoch 2/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0654 - accuracy: 0.9768 - val_loss: 0.3449 - val_accuracy: 0.8858
# Epoch 3/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0456 - accuracy: 0.9847 - val_loss: 0.5621 - val_accuracy: 0.8615
# Epoch 4/30
# 30/30 [==============================] - 1s 29ms/step - loss: 0.0266 - accuracy: 0.9916 - val_loss: 0.9060 - val_accuracy: 0.7896
# Epoch 5/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0196 - accuracy: 0.9929 - val_loss: 0.1514 - val_accuracy: 0.9493
# Epoch 6/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0164 - accuracy: 0.9945 - val_loss: 0.2446 - val_accuracy: 0.9440
# Epoch 7/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0201 - accuracy: 0.9945 - val_loss: 0.8381 - val_accuracy: 0.8076
# Epoch 8/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0211 - accuracy: 0.9916 - val_loss: 0.4168 - val_accuracy: 0.8922
# Epoch 9/30
# 30/30 [==============================] - 1s 33ms/step - loss: 0.0355 - accuracy: 0.9871 - val_loss: 0.0910 - val_accuracy: 0.9725
# Epoch 10/30
# 30/30 [==============================] - 1s 27ms/step - loss: 0.0246 - accuracy: 0.9913 - val_loss: 1.0307 - val_accuracy: 0.7632
# Epoch 11/30
# 30/30 [==============================] - 1s 30ms/step - loss: 0.0170 - accuracy: 0.9952 - val_loss: 0.1672 - val_accuracy: 0.9408
# Epoch 12/30
# 30/30 [==============================] - 1s 31ms/step - loss: 0.0158 - accuracy: 0.9942 - val_loss: 1.2367 - val_accuracy: 0.7886
# Epoch 13/30
# 30/30 [==============================] - 1s 32ms/step - loss: 0.0084 - accuracy: 0.9982 - val_loss: 0.9433 - val_accuracy: 0.8330
# Epoch 14/30
# 30/30 [==============================] - 1s 37ms/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 0.2110 - val_accuracy: 0.9419
# Best epoch for Fold 5: 9, Validation Loss: 0.0910, Validation Accuracy: 0.9725, Zero-One Loss: 0.0275
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model AlexNet_0.01 has been saved.
# Creating the model for AlexNet and learning rate is 0.1
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 4s 70ms/step - loss: 1.9891 - accuracy: 0.6072 - val_loss: 277.3370 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 1s 34ms/step - loss: 8.8530 - accuracy: 0.5811 - val_loss: 172.3933 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 1s 32ms/step - loss: nan - accuracy: 0.5269 - val_loss: nan - val_accuracy: 0.5491
# Epoch 4/30
# 30/30 [==============================] - 1s 31ms/step - loss: nan - accuracy: 0.5386 - val_loss: nan - val_accuracy: 0.5491
# Epoch 5/30
# 30/30 [==============================] - 1s 34ms/step - loss: nan - accuracy: 0.5386 - val_loss: nan - val_accuracy: 0.5491
# Epoch 6/30
# 30/30 [==============================] - 1s 32ms/step - loss: nan - accuracy: 0.5386 - val_loss: nan - val_accuracy: 0.5491
# Epoch 7/30
# 30/30 [==============================] - 1s 35ms/step - loss: nan - accuracy: 0.5386 - val_loss: nan - val_accuracy: 0.5491
# Best epoch for Fold 1: 3, Validation Loss: nan, Validation Accuracy: 0.5491, Zero-One Loss: 0.4509
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 35ms/step - loss: nan - accuracy: 0.5428 - val_loss: nan - val_accuracy: 0.5343
# Epoch 2/30
# 30/30 [==============================] - 1s 26ms/step - loss: nan - accuracy: 0.5423 - val_loss: nan - val_accuracy: 0.5343
# Epoch 3/30
# 30/30 [==============================] - 1s 26ms/step - loss: nan - accuracy: 0.5423 - val_loss: nan - val_accuracy: 0.5343
# Epoch 4/30
# 30/30 [==============================] - 1s 26ms/step - loss: nan - accuracy: 0.5423 - val_loss: nan - val_accuracy: 0.5343
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: nan - accuracy: 0.5423 - val_loss: nan - val_accuracy: 0.5343
# Best epoch for Fold 2: 1, Validation Loss: nan, Validation Accuracy: 0.5343, Zero-One Loss: 0.4657
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 34ms/step - loss: nan - accuracy: 0.5449 - val_loss: nan - val_accuracy: 0.5238
# Epoch 2/30
# 30/30 [==============================] - 1s 26ms/step - loss: nan - accuracy: 0.5449 - val_loss: nan - val_accuracy: 0.5238
# Epoch 3/30
# 30/30 [==============================] - 1s 29ms/step - loss: nan - accuracy: 0.5449 - val_loss: nan - val_accuracy: 0.5238
# Epoch 4/30
# 30/30 [==============================] - 1s 31ms/step - loss: nan - accuracy: 0.5449 - val_loss: nan - val_accuracy: 0.5238
# Epoch 5/30
# 30/30 [==============================] - 1s 35ms/step - loss: nan - accuracy: 0.5449 - val_loss: nan - val_accuracy: 0.5238
# Best epoch for Fold 3: 1, Validation Loss: nan, Validation Accuracy: 0.5238, Zero-One Loss: 0.4762
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 40ms/step - loss: nan - accuracy: 0.5400 - val_loss: nan - val_accuracy: 0.5433
# Epoch 2/30
# 30/30 [==============================] - 1s 29ms/step - loss: nan - accuracy: 0.5400 - val_loss: nan - val_accuracy: 0.5433
# Epoch 3/30
# 30/30 [==============================] - 1s 28ms/step - loss: nan - accuracy: 0.5400 - val_loss: nan - val_accuracy: 0.5433
# Epoch 4/30
# 30/30 [==============================] - 1s 26ms/step - loss: nan - accuracy: 0.5400 - val_loss: nan - val_accuracy: 0.5433
# Epoch 5/30
# 30/30 [==============================] - 1s 30ms/step - loss: nan - accuracy: 0.5400 - val_loss: nan - val_accuracy: 0.5433
# Best epoch for Fold 4: 1, Validation Loss: nan, Validation Accuracy: 0.5433, Zero-One Loss: 0.4567
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 1s 39ms/step - loss: nan - accuracy: 0.5376 - val_loss: nan - val_accuracy: 0.5529
# Epoch 2/30
# 30/30 [==============================] - 1s 31ms/step - loss: nan - accuracy: 0.5376 - val_loss: nan - val_accuracy: 0.5529
# Epoch 3/30
# 30/30 [==============================] - 1s 31ms/step - loss: nan - accuracy: 0.5376 - val_loss: nan - val_accuracy: 0.5529
# Epoch 4/30
# 30/30 [==============================] - 1s 32ms/step - loss: nan - accuracy: 0.5376 - val_loss: nan - val_accuracy: 0.5529
# Epoch 5/30
# 30/30 [==============================] - 1s 34ms/step - loss: nan - accuracy: 0.5376 - val_loss: nan - val_accuracy: 0.5529
# Best epoch for Fold 5: 1, Validation Loss: nan, Validation Accuracy: 0.5529, Zero-One Loss: 0.4471
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model AlexNet_0.1 has been saved.
# Creating the model for ResNet and learning rate is 0.005
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 19s 191ms/step - loss: 0.6318 - accuracy: 0.6907 - val_loss: 1.6113 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.3812 - accuracy: 0.8384 - val_loss: 1.0757 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 3s 96ms/step - loss: 0.2583 - accuracy: 0.9004 - val_loss: 0.7710 - val_accuracy: 0.5491
# Epoch 4/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.1724 - accuracy: 0.9303 - val_loss: 0.7259 - val_accuracy: 0.5502
# Epoch 5/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.1344 - accuracy: 0.9509 - val_loss: 0.9746 - val_accuracy: 0.5512
# Epoch 6/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.1134 - accuracy: 0.9596 - val_loss: 0.8289 - val_accuracy: 0.5913
# Epoch 7/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0910 - accuracy: 0.9675 - val_loss: 1.0725 - val_accuracy: 0.6304
# Epoch 8/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0526 - accuracy: 0.9823 - val_loss: 0.9617 - val_accuracy: 0.7054
# Epoch 9/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0762 - accuracy: 0.9749 - val_loss: 0.4179 - val_accuracy: 0.8427
# Epoch 10/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1020 - accuracy: 0.9612 - val_loss: 0.4189 - val_accuracy: 0.8437
# Epoch 11/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.0396 - accuracy: 0.9860 - val_loss: 0.4962 - val_accuracy: 0.8511
# Epoch 12/30
# 30/30 [==============================] - 3s 90ms/step - loss: 0.0209 - accuracy: 0.9905 - val_loss: 0.7914 - val_accuracy: 0.8068
# Epoch 13/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0196 - accuracy: 0.9934 - val_loss: 0.8144 - val_accuracy: 0.8237
# Epoch 14/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0102 - accuracy: 0.9958 - val_loss: 0.7360 - val_accuracy: 0.8606
# Best epoch for Fold 1: 9, Validation Loss: 0.4179, Validation Accuracy: 0.8427, Zero-One Loss: 0.1573
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 103ms/step - loss: 0.1578 - accuracy: 0.9466 - val_loss: 0.6969 - val_accuracy: 0.7244
# Epoch 2/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0577 - accuracy: 0.9828 - val_loss: 0.4645 - val_accuracy: 0.8363
# Epoch 3/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0176 - accuracy: 0.9950 - val_loss: 0.1411 - val_accuracy: 0.9546
# Epoch 4/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0277 - accuracy: 0.9902 - val_loss: 0.1977 - val_accuracy: 0.9430
# Epoch 5/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0528 - accuracy: 0.9812 - val_loss: 0.2021 - val_accuracy: 0.9388
# Epoch 6/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0393 - accuracy: 0.9878 - val_loss: 0.4739 - val_accuracy: 0.8933
# Epoch 7/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0265 - accuracy: 0.9921 - val_loss: 0.3132 - val_accuracy: 0.9081
# Epoch 8/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0166 - accuracy: 0.9945 - val_loss: 0.4719 - val_accuracy: 0.8701
# Best epoch for Fold 2: 3, Validation Loss: 0.1411, Validation Accuracy: 0.9546, Zero-One Loss: 0.0454
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 99ms/step - loss: 0.0537 - accuracy: 0.9791 - val_loss: 0.8255 - val_accuracy: 0.8215
# Epoch 2/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0637 - accuracy: 0.9757 - val_loss: 0.2596 - val_accuracy: 0.9124
# Epoch 3/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0393 - accuracy: 0.9865 - val_loss: 0.1157 - val_accuracy: 0.9578
# Epoch 4/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0219 - accuracy: 0.9915 - val_loss: 0.2484 - val_accuracy: 0.9208
# Epoch 5/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0150 - accuracy: 0.9945 - val_loss: 0.8411 - val_accuracy: 0.8374
# Epoch 6/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0266 - accuracy: 0.9905 - val_loss: 0.1986 - val_accuracy: 0.9377
# Epoch 7/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0405 - accuracy: 0.9863 - val_loss: 0.5005 - val_accuracy: 0.8691
# Epoch 8/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0395 - accuracy: 0.9857 - val_loss: 0.3068 - val_accuracy: 0.9071
# Best epoch for Fold 3: 3, Validation Loss: 0.1157, Validation Accuracy: 0.9578, Zero-One Loss: 0.0422
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 6s 196ms/step - loss: 0.0498 - accuracy: 0.9823 - val_loss: 0.1167 - val_accuracy: 0.9567
# Epoch 2/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0573 - accuracy: 0.9768 - val_loss: 0.1542 - val_accuracy: 0.9493
# Epoch 3/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0397 - accuracy: 0.9865 - val_loss: 0.2108 - val_accuracy: 0.9376
# Epoch 4/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0224 - accuracy: 0.9921 - val_loss: 0.5096 - val_accuracy: 0.8795
# Epoch 5/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0141 - accuracy: 0.9960 - val_loss: 0.1845 - val_accuracy: 0.9408
# Epoch 6/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0045 - accuracy: 0.9984 - val_loss: 0.1515 - val_accuracy: 0.9567
# Best epoch for Fold 4: 1, Validation Loss: 0.1167, Validation Accuracy: 0.9567, Zero-One Loss: 0.0433
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 105ms/step - loss: 0.0389 - accuracy: 0.9842 - val_loss: 0.1881 - val_accuracy: 0.9366
# Epoch 2/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0398 - accuracy: 0.9852 - val_loss: 0.1724 - val_accuracy: 0.9355
# Epoch 3/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0286 - accuracy: 0.9886 - val_loss: 0.9551 - val_accuracy: 0.7812
# Epoch 4/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0150 - accuracy: 0.9952 - val_loss: 0.6966 - val_accuracy: 0.8457
# Epoch 5/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0132 - accuracy: 0.9963 - val_loss: 0.2470 - val_accuracy: 0.9345
# Epoch 6/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0116 - accuracy: 0.9963 - val_loss: 0.2088 - val_accuracy: 0.9355
# Epoch 7/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0126 - accuracy: 0.9960 - val_loss: 0.1709 - val_accuracy: 0.9429
# Epoch 8/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0070 - accuracy: 0.9976 - val_loss: 0.2974 - val_accuracy: 0.9197
# Epoch 9/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0110 - accuracy: 0.9960 - val_loss: 0.0689 - val_accuracy: 0.9778
# Epoch 10/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0059 - accuracy: 0.9982 - val_loss: 0.1950 - val_accuracy: 0.9419
# Epoch 11/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0103 - accuracy: 0.9974 - val_loss: 0.0868 - val_accuracy: 0.9757
# Epoch 12/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0106 - accuracy: 0.9950 - val_loss: 0.2285 - val_accuracy: 0.9524
# Epoch 13/30
# 30/30 [==============================] - 3s 90ms/step - loss: 0.0102 - accuracy: 0.9966 - val_loss: 0.1905 - val_accuracy: 0.9493
# Epoch 14/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0216 - accuracy: 0.9923 - val_loss: 0.1966 - val_accuracy: 0.9397
# Best epoch for Fold 5: 9, Validation Loss: 0.0689, Validation Accuracy: 0.9778, Zero-One Loss: 0.0222
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model ResNet_0.005 has been saved.
# Creating the model for ResNet and learning rate is 0.01
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 13s 119ms/step - loss: 0.6150 - accuracy: 0.7039 - val_loss: 4.8019 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.4156 - accuracy: 0.8283 - val_loss: 2.1055 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.3107 - accuracy: 0.8761 - val_loss: 1.4126 - val_accuracy: 0.5597
# Epoch 4/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.2336 - accuracy: 0.9083 - val_loss: 0.7910 - val_accuracy: 0.6304
# Epoch 5/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.1762 - accuracy: 0.9332 - val_loss: 0.5850 - val_accuracy: 0.6969
# Epoch 6/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1788 - accuracy: 0.9297 - val_loss: 0.7795 - val_accuracy: 0.6526
# Epoch 7/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.1061 - accuracy: 0.9649 - val_loss: 0.5122 - val_accuracy: 0.8057
# Epoch 8/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.1364 - accuracy: 0.9506 - val_loss: 0.4395 - val_accuracy: 0.8416
# Epoch 9/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0651 - accuracy: 0.9781 - val_loss: 0.4463 - val_accuracy: 0.8701
# Epoch 10/30
# 30/30 [==============================] - 3s 90ms/step - loss: 0.0557 - accuracy: 0.9802 - val_loss: 2.6687 - val_accuracy: 0.5903
# Epoch 11/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0770 - accuracy: 0.9715 - val_loss: 1.2418 - val_accuracy: 0.7086
# Epoch 12/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0594 - accuracy: 0.9794 - val_loss: 0.4722 - val_accuracy: 0.8596
# Epoch 13/30
# 30/30 [==============================] - 3s 97ms/step - loss: 0.0680 - accuracy: 0.9749 - val_loss: 1.2805 - val_accuracy: 0.7012
# Best epoch for Fold 1: 8, Validation Loss: 0.4395, Validation Accuracy: 0.8416, Zero-One Loss: 0.1584
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 102ms/step - loss: 0.1529 - accuracy: 0.9474 - val_loss: 0.3388 - val_accuracy: 0.8722
# Epoch 2/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0790 - accuracy: 0.9746 - val_loss: 0.1612 - val_accuracy: 0.9335
# Epoch 3/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0726 - accuracy: 0.9707 - val_loss: 1.2741 - val_accuracy: 0.6969
# Epoch 4/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0552 - accuracy: 0.9781 - val_loss: 0.8483 - val_accuracy: 0.7687
# Epoch 5/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0420 - accuracy: 0.9844 - val_loss: 0.6637 - val_accuracy: 0.8289
# Epoch 6/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0454 - accuracy: 0.9852 - val_loss: 0.3075 - val_accuracy: 0.9145
# Epoch 7/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0614 - accuracy: 0.9781 - val_loss: 1.1008 - val_accuracy: 0.7529
# Best epoch for Fold 2: 2, Validation Loss: 0.1612, Validation Accuracy: 0.9335, Zero-One Loss: 0.0665
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 100ms/step - loss: 0.0632 - accuracy: 0.9791 - val_loss: 1.1433 - val_accuracy: 0.7128
# Epoch 2/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0741 - accuracy: 0.9725 - val_loss: 0.6005 - val_accuracy: 0.8342
# Epoch 3/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0628 - accuracy: 0.9757 - val_loss: 1.0060 - val_accuracy: 0.7518
# Epoch 4/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0413 - accuracy: 0.9849 - val_loss: 1.3218 - val_accuracy: 0.7297
# Epoch 5/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.0328 - accuracy: 0.9881 - val_loss: 0.8724 - val_accuracy: 0.7920
# Epoch 6/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0282 - accuracy: 0.9897 - val_loss: 0.5058 - val_accuracy: 0.8511
# Epoch 7/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0339 - accuracy: 0.9889 - val_loss: 1.3203 - val_accuracy: 0.7307
# Epoch 8/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0240 - accuracy: 0.9921 - val_loss: 0.2725 - val_accuracy: 0.9293
# Epoch 9/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0270 - accuracy: 0.9910 - val_loss: 0.3378 - val_accuracy: 0.9039
# Epoch 10/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0333 - accuracy: 0.9871 - val_loss: 0.2978 - val_accuracy: 0.9282
# Epoch 11/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0228 - accuracy: 0.9918 - val_loss: 0.2469 - val_accuracy: 0.9324
# Epoch 12/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0136 - accuracy: 0.9963 - val_loss: 1.0945 - val_accuracy: 0.8046
# Epoch 13/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0141 - accuracy: 0.9942 - val_loss: 1.0643 - val_accuracy: 0.8152
# Epoch 14/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0262 - accuracy: 0.9908 - val_loss: 1.2279 - val_accuracy: 0.7719
# Epoch 15/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 0.2425 - val_accuracy: 0.9345
# Epoch 16/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0081 - accuracy: 0.9968 - val_loss: 0.7966 - val_accuracy: 0.8448
# Epoch 17/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0142 - accuracy: 0.9952 - val_loss: 1.1673 - val_accuracy: 0.8089
# Epoch 18/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0287 - accuracy: 0.9905 - val_loss: 0.2444 - val_accuracy: 0.9324
# Epoch 19/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0131 - accuracy: 0.9963 - val_loss: 0.3133 - val_accuracy: 0.9229
# Epoch 20/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0156 - accuracy: 0.9942 - val_loss: 0.3751 - val_accuracy: 0.9219
# Best epoch for Fold 3: 15, Validation Loss: 0.2425, Validation Accuracy: 0.9345, Zero-One Loss: 0.0655
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 98ms/step - loss: 0.0785 - accuracy: 0.9754 - val_loss: 0.6169 - val_accuracy: 0.8023
# Epoch 2/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.0283 - accuracy: 0.9902 - val_loss: 0.0601 - val_accuracy: 0.9820
# Epoch 3/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.0133 - accuracy: 0.9950 - val_loss: 0.2601 - val_accuracy: 0.9228
# Epoch 4/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0069 - accuracy: 0.9974 - val_loss: 1.8139 - val_accuracy: 0.7315
# Epoch 5/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0043 - accuracy: 0.9982 - val_loss: 0.0710 - val_accuracy: 0.9799
# Epoch 6/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.0298 - accuracy: 0.9908 - val_loss: 0.1801 - val_accuracy: 0.9408
# Epoch 7/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0338 - accuracy: 0.9886 - val_loss: 0.0513 - val_accuracy: 0.9789
# Epoch 8/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.0145 - accuracy: 0.9958 - val_loss: 0.0240 - val_accuracy: 0.9905
# Epoch 9/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.0106 - val_accuracy: 0.9947
# Epoch 10/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.0325 - val_accuracy: 0.9915
# Epoch 11/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0030 - accuracy: 0.9989 - val_loss: 0.0129 - val_accuracy: 0.9958
# Epoch 12/30
# 30/30 [==============================] - 3s 84ms/step - loss: 0.0027 - accuracy: 0.9992 - val_loss: 0.0155 - val_accuracy: 0.9947
# Epoch 13/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0039 - val_accuracy: 0.9989
# Epoch 14/30
# 30/30 [==============================] - 3s 89ms/step - loss: 5.1692e-04 - accuracy: 1.0000 - val_loss: 0.0026 - val_accuracy: 1.0000
# Epoch 15/30
# 30/30 [==============================] - 3s 87ms/step - loss: 1.4658e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 0.9968
# Epoch 16/30
# 30/30 [==============================] - 3s 85ms/step - loss: 1.7352e-04 - accuracy: 1.0000 - val_loss: 0.0044 - val_accuracy: 0.9989
# Epoch 17/30
# 30/30 [==============================] - 3s 91ms/step - loss: 3.0854e-04 - accuracy: 1.0000 - val_loss: 0.0149 - val_accuracy: 0.9937
# Epoch 18/30
# 30/30 [==============================] - 3s 91ms/step - loss: 3.2387e-04 - accuracy: 1.0000 - val_loss: 0.0182 - val_accuracy: 0.9937
# Epoch 19/30
# 30/30 [==============================] - 3s 94ms/step - loss: 1.5869e-04 - accuracy: 1.0000 - val_loss: 0.0059 - val_accuracy: 0.9968
# Best epoch for Fold 4: 14, Validation Loss: 0.0026, Validation Accuracy: 1.0000, Zero-One Loss: 0.0000
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 100ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 2.2178e-04 - val_accuracy: 1.0000
# Epoch 2/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.0145 - accuracy: 0.9963 - val_loss: 0.0193 - val_accuracy: 0.9905
# Epoch 3/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0152 - accuracy: 0.9955 - val_loss: 0.0361 - val_accuracy: 0.9884
# Epoch 4/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.0079 - accuracy: 0.9963 - val_loss: 0.1519 - val_accuracy: 0.9577
# Epoch 5/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0480 - val_accuracy: 0.9810
# Epoch 6/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.0045 - accuracy: 0.9982 - val_loss: 0.0134 - val_accuracy: 0.9968
# Best epoch for Fold 5: 1, Validation Loss: 0.0002, Validation Accuracy: 1.0000, Zero-One Loss: 0.0000
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model ResNet_0.01 has been saved.
# Creating the model for ResNet and learning rate is 0.1
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 15s 117ms/step - loss: 0.9840 - accuracy: 0.5460 - val_loss: 164245712.0000 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.6865 - accuracy: 0.5663 - val_loss: 1017287.6250 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.9432 - accuracy: 0.5573 - val_loss: 17446.1152 - val_accuracy: 0.5491
# Epoch 4/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.6548 - accuracy: 0.5792 - val_loss: 382.8013 - val_accuracy: 0.5449
# Epoch 5/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.6439 - accuracy: 0.5824 - val_loss: 51.6042 - val_accuracy: 0.5480
# Epoch 6/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.6457 - accuracy: 0.5766 - val_loss: 26.4261 - val_accuracy: 0.5491
# Epoch 7/30
# 30/30 [==============================] - 3s 96ms/step - loss: 0.6413 - accuracy: 0.5858 - val_loss: 5.0544 - val_accuracy: 0.5206
# Epoch 8/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.6421 - accuracy: 0.5890 - val_loss: 1.8165 - val_accuracy: 0.5491
# Epoch 9/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.6391 - accuracy: 0.5737 - val_loss: 0.7148 - val_accuracy: 0.5544
# Epoch 10/30
# 30/30 [==============================] - 3s 96ms/step - loss: 0.6004 - accuracy: 0.6920 - val_loss: 0.6212 - val_accuracy: 0.6917
# Epoch 11/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.5116 - accuracy: 0.7734 - val_loss: 0.9781 - val_accuracy: 0.5829
# Epoch 12/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.4533 - accuracy: 0.8141 - val_loss: 1.0815 - val_accuracy: 0.5829
# Epoch 13/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.4020 - accuracy: 0.8460 - val_loss: 1.1990 - val_accuracy: 0.5586
# Epoch 14/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.3847 - accuracy: 0.8550 - val_loss: 1.2005 - val_accuracy: 0.6589
# Epoch 15/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.3523 - accuracy: 0.8584 - val_loss: 0.6284 - val_accuracy: 0.7909
# Best epoch for Fold 1: 10, Validation Loss: 0.6212, Validation Accuracy: 0.6917, Zero-One Loss: 0.3083
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.5000 - accuracy: 0.7863 - val_loss: 0.5794 - val_accuracy: 0.7254
# Epoch 2/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.4321 - accuracy: 0.8265 - val_loss: 1.0814 - val_accuracy: 0.5818
# Epoch 3/30
# 30/30 [==============================] - 3s 92ms/step - loss: 0.4130 - accuracy: 0.8426 - val_loss: 1.1249 - val_accuracy: 0.6505
# Epoch 4/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.3566 - accuracy: 0.8671 - val_loss: 1.0930 - val_accuracy: 0.6220
# Epoch 5/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.3607 - accuracy: 0.8669 - val_loss: 0.6165 - val_accuracy: 0.7233
# Epoch 6/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.3204 - accuracy: 0.8780 - val_loss: 0.9691 - val_accuracy: 0.6843
# Best epoch for Fold 2: 1, Validation Loss: 0.5794, Validation Accuracy: 0.7254, Zero-One Loss: 0.2746
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 93ms/step - loss: 0.4308 - accuracy: 0.8310 - val_loss: 1.1957 - val_accuracy: 0.5966
# Epoch 2/30
# 30/30 [==============================] - 3s 91ms/step - loss: 0.3974 - accuracy: 0.8537 - val_loss: 0.8078 - val_accuracy: 0.6188
# Epoch 3/30
# 30/30 [==============================] - 2s 83ms/step - loss: 0.3867 - accuracy: 0.8487 - val_loss: 1.3661 - val_accuracy: 0.6294
# Epoch 4/30
# 30/30 [==============================] - 3s 90ms/step - loss: 0.3404 - accuracy: 0.8714 - val_loss: 1.8084 - val_accuracy: 0.5512
# Epoch 5/30
# 30/30 [==============================] - 3s 90ms/step - loss: 0.3315 - accuracy: 0.8759 - val_loss: 0.7092 - val_accuracy: 0.7466
# Epoch 6/30
# 30/30 [==============================] - 3s 87ms/step - loss: 0.2867 - accuracy: 0.8780 - val_loss: 0.5276 - val_accuracy: 0.8173
# Epoch 7/30
# 30/30 [==============================] - 3s 89ms/step - loss: 0.2896 - accuracy: 0.8951 - val_loss: 0.6655 - val_accuracy: 0.7170
# Epoch 8/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.2861 - accuracy: 0.8928 - val_loss: 0.3390 - val_accuracy: 0.8606
# Epoch 9/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.2659 - accuracy: 0.8986 - val_loss: 0.4725 - val_accuracy: 0.8395
# Epoch 10/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.2420 - accuracy: 0.9081 - val_loss: 1.6384 - val_accuracy: 0.6220
# Epoch 11/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.2310 - accuracy: 0.9149 - val_loss: 0.4075 - val_accuracy: 0.8564
# Epoch 12/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.2295 - accuracy: 0.9065 - val_loss: 0.4356 - val_accuracy: 0.8522
# Epoch 13/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.2009 - accuracy: 0.9216 - val_loss: 1.1909 - val_accuracy: 0.5903
# Best epoch for Fold 3: 8, Validation Loss: 0.3390, Validation Accuracy: 0.8606, Zero-One Loss: 0.1394
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 3s 99ms/step - loss: 0.2880 - accuracy: 0.8912 - val_loss: 1.2156 - val_accuracy: 0.6395
# Epoch 2/30
# 30/30 [==============================] - 3s 88ms/step - loss: 0.2607 - accuracy: 0.9039 - val_loss: 1.6616 - val_accuracy: 0.5476
# Epoch 3/30
# 30/30 [==============================] - 3s 94ms/step - loss: 0.2456 - accuracy: 0.9071 - val_loss: 0.4736 - val_accuracy: 0.8076
# Epoch 4/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.2365 - accuracy: 0.9118 - val_loss: 0.6580 - val_accuracy: 0.7579
# Epoch 5/30
# 30/30 [==============================] - 3s 85ms/step - loss: 0.2317 - accuracy: 0.9081 - val_loss: 1.5818 - val_accuracy: 0.5825
# Epoch 6/30
# 30/30 [==============================] - 3s 90ms/step - loss: 0.2128 - accuracy: 0.9200 - val_loss: 1.8759 - val_accuracy: 0.5518
# Epoch 7/30
# 30/30 [==============================] - 3s 86ms/step - loss: 0.1976 - accuracy: 0.9274 - val_loss: 0.6083 - val_accuracy: 0.7748
# Epoch 8/30
# 30/30 [==============================] - 3s 95ms/step - loss: 0.2010 - accuracy: 0.9269 - val_loss: 1.1270 - val_accuracy: 0.7410
# Best epoch for Fold 4: 3, Validation Loss: 0.4736, Validation Accuracy: 0.8076, Zero-One Loss: 0.1924
# ==== Training Fold 5 ====
# Epoch 1/30
# ...
# Epoch 19/30
# 30/30 [==============================] - 5s 176ms/step - loss: 0.4260 - accuracy: 0.8104 - val_loss: 0.3950 - val_accuracy: 0.8036
# Epoch 20/30
# 30/30 [==============================] - 5s 161ms/step - loss: 0.3961 - accuracy: 0.8275 - val_loss: 0.3540 - val_accuracy: 0.8405
# Epoch 21/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.3760 - accuracy: 0.8354 - val_loss: 0.4127 - val_accuracy: 0.8004
# Epoch 22/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.3642 - accuracy: 0.8447 - val_loss: 0.3442 - val_accuracy: 0.8522
# Epoch 23/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.3822 - accuracy: 0.8357 - val_loss: 0.3695 - val_accuracy: 0.8543
# Epoch 24/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.3586 - accuracy: 0.8444 - val_loss: 0.3533 - val_accuracy: 0.8511
# Epoch 25/30
# 30/30 [==============================] - 5s 164ms/step - loss: 0.3355 - accuracy: 0.8624 - val_loss: 0.3319 - val_accuracy: 0.8669
# Epoch 26/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.3491 - accuracy: 0.8513 - val_loss: 0.3235 - val_accuracy: 0.8606
# Epoch 27/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.3811 - accuracy: 0.8317 - val_loss: 0.4315 - val_accuracy: 0.7962
# Epoch 28/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.3354 - accuracy: 0.8642 - val_loss: 0.3660 - val_accuracy: 0.8353
# Epoch 29/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.3346 - accuracy: 0.8600 - val_loss: 0.3003 - val_accuracy: 0.8701
# Epoch 30/30
# 30/30 [==============================] - 5s 174ms/step - loss: 0.3162 - accuracy: 0.8682 - val_loss: 0.2849 - val_accuracy: 0.8765
# Best epoch for Fold 1: 30, Validation Loss: 0.2849, Validation Accuracy: 0.8765, Zero-One Loss: 0.1235
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2934 - accuracy: 0.8811 - val_loss: 0.2809 - val_accuracy: 0.8838
# Epoch 2/30
# 30/30 [==============================] - 5s 173ms/step - loss: 0.2788 - accuracy: 0.8825 - val_loss: 0.2794 - val_accuracy: 0.8976
# Epoch 3/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.3384 - accuracy: 0.8603 - val_loss: 0.2978 - val_accuracy: 0.8838
# Epoch 4/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.2809 - accuracy: 0.8830 - val_loss: 0.3803 - val_accuracy: 0.8427
# Epoch 5/30
# 30/30 [==============================] - 5s 158ms/step - loss: 0.2918 - accuracy: 0.8788 - val_loss: 0.3839 - val_accuracy: 0.8395
# Epoch 6/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.2979 - accuracy: 0.8774 - val_loss: 0.2988 - val_accuracy: 0.8923
# Epoch 7/30
# 30/30 [==============================] - 5s 163ms/step - loss: 0.2630 - accuracy: 0.8938 - val_loss: 0.2596 - val_accuracy: 0.9007
# Epoch 8/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.2563 - accuracy: 0.8941 - val_loss: 0.2916 - val_accuracy: 0.8817
# Epoch 9/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.2445 - accuracy: 0.8973 - val_loss: 0.2662 - val_accuracy: 0.9007
# Epoch 10/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2373 - accuracy: 0.8999 - val_loss: 0.2596 - val_accuracy: 0.9060
# Epoch 11/30
# 30/30 [==============================] - 5s 158ms/step - loss: 0.2505 - accuracy: 0.8991 - val_loss: 0.3118 - val_accuracy: 0.8659
# Epoch 12/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.2728 - accuracy: 0.8904 - val_loss: 0.2820 - val_accuracy: 0.8807
# Epoch 13/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.2241 - accuracy: 0.9091 - val_loss: 0.2948 - val_accuracy: 0.8891
# Epoch 14/30
# 30/30 [==============================] - 5s 174ms/step - loss: 0.2121 - accuracy: 0.9184 - val_loss: 0.2487 - val_accuracy: 0.9092
# Epoch 15/30
# 30/30 [==============================] - 5s 157ms/step - loss: 0.2318 - accuracy: 0.9078 - val_loss: 0.2876 - val_accuracy: 0.8891
# Epoch 16/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.2532 - accuracy: 0.8986 - val_loss: 0.2849 - val_accuracy: 0.8881
# Epoch 17/30
# 30/30 [==============================] - 5s 158ms/step - loss: 0.2235 - accuracy: 0.9091 - val_loss: 0.2542 - val_accuracy: 0.9018
# Epoch 18/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.2026 - accuracy: 0.9197 - val_loss: 0.2508 - val_accuracy: 0.9050
# Epoch 19/30
# 30/30 [==============================] - 5s 176ms/step - loss: 0.1816 - accuracy: 0.9329 - val_loss: 0.2622 - val_accuracy: 0.9060
# Best epoch for Fold 2: 14, Validation Loss: 0.2487, Validation Accuracy: 0.9092, Zero-One Loss: 0.0908
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.2416 - accuracy: 0.9070 - val_loss: 0.2042 - val_accuracy: 0.9102
# Epoch 2/30
# 30/30 [==============================] - 5s 172ms/step - loss: 0.2210 - accuracy: 0.9189 - val_loss: 0.1914 - val_accuracy: 0.9261
# Epoch 3/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.1979 - accuracy: 0.9287 - val_loss: 0.2314 - val_accuracy: 0.9113
# Epoch 4/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.1905 - accuracy: 0.9268 - val_loss: 0.2266 - val_accuracy: 0.9092
# Epoch 5/30
# 30/30 [==============================] - 5s 159ms/step - loss: 0.2292 - accuracy: 0.9046 - val_loss: 0.2295 - val_accuracy: 0.9081
# Epoch 6/30
# 30/30 [==============================] - 5s 163ms/step - loss: 0.1988 - accuracy: 0.9155 - val_loss: 0.2373 - val_accuracy: 0.9092
# Epoch 7/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.1967 - accuracy: 0.9200 - val_loss: 0.1922 - val_accuracy: 0.9271
# Best epoch for Fold 3: 2, Validation Loss: 0.1914, Validation Accuracy: 0.9261, Zero-One Loss: 0.0739
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 179ms/step - loss: 0.2082 - accuracy: 0.9160 - val_loss: 0.2574 - val_accuracy: 0.8911
# Epoch 2/30
# 30/30 [==============================] - 5s 160ms/step - loss: 0.2577 - accuracy: 0.8949 - val_loss: 0.1681 - val_accuracy: 0.9366
# Epoch 3/30
# 30/30 [==============================] - 5s 155ms/step - loss: 0.2006 - accuracy: 0.9226 - val_loss: 0.1716 - val_accuracy: 0.9260
# Epoch 4/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.1843 - accuracy: 0.9303 - val_loss: 0.1292 - val_accuracy: 0.9588
# Epoch 5/30
# 30/30 [==============================] - 5s 155ms/step - loss: 0.1804 - accuracy: 0.9242 - val_loss: 0.1562 - val_accuracy: 0.9302
# Epoch 6/30
# 30/30 [==============================] - 5s 166ms/step - loss: 0.1665 - accuracy: 0.9348 - val_loss: 0.2386 - val_accuracy: 0.9197
# Epoch 7/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.1723 - accuracy: 0.9353 - val_loss: 0.1860 - val_accuracy: 0.9313
# Epoch 8/30
# 30/30 [==============================] - 5s 155ms/step - loss: 0.1522 - accuracy: 0.9395 - val_loss: 0.1400 - val_accuracy: 0.9524
# Epoch 9/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.1649 - accuracy: 0.9372 - val_loss: 0.1770 - val_accuracy: 0.9281
# Best epoch for Fold 4: 4, Validation Loss: 0.1292, Validation Accuracy: 0.9588, Zero-One Loss: 0.0412
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 179ms/step - loss: 0.1764 - accuracy: 0.9321 - val_loss: 0.1708 - val_accuracy: 0.9387
# Epoch 2/30
# 30/30 [==============================] - 5s 166ms/step - loss: 0.1727 - accuracy: 0.9335 - val_loss: 0.2299 - val_accuracy: 0.9101
# Epoch 3/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.1905 - accuracy: 0.9232 - val_loss: 0.2003 - val_accuracy: 0.9154
# Epoch 4/30
# 30/30 [==============================] - 5s 158ms/step - loss: 0.2042 - accuracy: 0.9158 - val_loss: 0.2371 - val_accuracy: 0.9080
# Epoch 5/30
# 30/30 [==============================] - 5s 169ms/step - loss: 0.1749 - accuracy: 0.9350 - val_loss: 0.1915 - val_accuracy: 0.9271
# Epoch 6/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.1575 - accuracy: 0.9409 - val_loss: 0.2052 - val_accuracy: 0.9091
# Best epoch for Fold 5: 1, Validation Loss: 0.1708, Validation Accuracy: 0.9387, Zero-One Loss: 0.0613
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model VGG16_0.01 has been saved.
# Creating the model for VGG16 and learning rate is 0.1
# ==== Training Fold 1 ====
# Epoch 1/30
# 30/30 [==============================] - 8s 212ms/step - loss: 0.6906 - accuracy: 0.5354 - val_loss: 0.6888 - val_accuracy: 0.5491
# Epoch 2/30
# 30/30 [==============================] - 5s 164ms/step - loss: 0.6902 - accuracy: 0.5380 - val_loss: 0.6888 - val_accuracy: 0.5491
# Epoch 3/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.6887 - accuracy: 0.5330 - val_loss: 0.6522 - val_accuracy: 0.6653
# Epoch 4/30
# 30/30 [==============================] - 5s 164ms/step - loss: 0.6966 - accuracy: 0.5254 - val_loss: 0.6883 - val_accuracy: 0.5491
# Epoch 5/30
# 30/30 [==============================] - 5s 154ms/step - loss: 0.6938 - accuracy: 0.5306 - val_loss: 0.7022 - val_accuracy: 0.4509
# Epoch 6/30
# 30/30 [==============================] - 5s 151ms/step - loss: 0.6919 - accuracy: 0.5335 - val_loss: 0.6899 - val_accuracy: 0.5491
# Epoch 7/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.6907 - accuracy: 0.5386 - val_loss: 0.6884 - val_accuracy: 0.5491
# Epoch 8/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.6911 - accuracy: 0.5386 - val_loss: 0.6889 - val_accuracy: 0.5491
# Best epoch for Fold 1: 3, Validation Loss: 0.6522, Validation Accuracy: 0.6653, Zero-One Loss: 0.3347
# ==== Training Fold 2 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 177ms/step - loss: 0.6914 - accuracy: 0.5367 - val_loss: 0.6913 - val_accuracy: 0.5343
# Epoch 2/30
# 30/30 [==============================] - 5s 165ms/step - loss: 0.6921 - accuracy: 0.5378 - val_loss: 0.6934 - val_accuracy: 0.5343
# Epoch 3/30
# 30/30 [==============================] - 5s 159ms/step - loss: 0.6912 - accuracy: 0.5428 - val_loss: 0.6911 - val_accuracy: 0.5343
# Epoch 4/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.6921 - accuracy: 0.5214 - val_loss: 0.6913 - val_accuracy: 0.5343
# Epoch 5/30
# 30/30 [==============================] - 5s 172ms/step - loss: 0.6905 - accuracy: 0.5401 - val_loss: 0.6907 - val_accuracy: 0.5343
# Epoch 6/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.6903 - accuracy: 0.5425 - val_loss: 0.6947 - val_accuracy: 0.5343
# Epoch 7/30
# 30/30 [==============================] - 5s 168ms/step - loss: 0.6921 - accuracy: 0.5404 - val_loss: 0.6921 - val_accuracy: 0.5343
# Epoch 8/30
# 30/30 [==============================] - 5s 156ms/step - loss: 0.6901 - accuracy: 0.5394 - val_loss: 0.6965 - val_accuracy: 0.5343
# Epoch 9/30
# 30/30 [==============================] - 5s 160ms/step - loss: 0.6886 - accuracy: 0.5446 - val_loss: 0.6794 - val_accuracy: 0.5333
# Epoch 10/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6990 - accuracy: 0.5174 - val_loss: 0.6910 - val_accuracy: 0.5343
# Epoch 11/30
# 30/30 [==============================] - 5s 152ms/step - loss: 0.6901 - accuracy: 0.5423 - val_loss: 0.6908 - val_accuracy: 0.5343
# Epoch 12/30
# 30/30 [==============================] - 5s 151ms/step - loss: 0.6925 - accuracy: 0.5166 - val_loss: 0.6915 - val_accuracy: 0.5343
# Epoch 13/30
# 30/30 [==============================] - 5s 163ms/step - loss: 0.6914 - accuracy: 0.5230 - val_loss: 0.6932 - val_accuracy: 0.5343
# Epoch 14/30
# 30/30 [==============================] - 5s 157ms/step - loss: 0.6909 - accuracy: 0.5423 - val_loss: 0.6927 - val_accuracy: 0.5343
# Best epoch for Fold 2: 9, Validation Loss: 0.6794, Validation Accuracy: 0.5333, Zero-One Loss: 0.4667
# ==== Training Fold 3 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 166ms/step - loss: 0.6933 - accuracy: 0.5256 - val_loss: 0.6924 - val_accuracy: 0.5238
# Epoch 2/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.6905 - accuracy: 0.5449 - val_loss: 0.6920 - val_accuracy: 0.5238
# Epoch 3/30
# 30/30 [==============================] - 5s 152ms/step - loss: 0.6909 - accuracy: 0.5452 - val_loss: 0.6936 - val_accuracy: 0.5238
# Epoch 4/30
# 30/30 [==============================] - 5s 162ms/step - loss: 0.6904 - accuracy: 0.5449 - val_loss: 0.6940 - val_accuracy: 0.5238
# Epoch 5/30
# 30/30 [==============================] - 5s 153ms/step - loss: 0.6897 - accuracy: 0.5449 - val_loss: 0.6928 - val_accuracy: 0.5238
# Epoch 6/30
# 30/30 [==============================] - 5s 153ms/step - loss: 0.6888 - accuracy: 0.5449 - val_loss: 0.6930 - val_accuracy: 0.5238
# Epoch 7/30
# 30/30 [==============================] - 5s 158ms/step - loss: 0.6908 - accuracy: 0.5375 - val_loss: 0.6986 - val_accuracy: 0.5238
# Best epoch for Fold 3: 2, Validation Loss: 0.6920, Validation Accuracy: 0.5238, Zero-One Loss: 0.4762
# ==== Training Fold 4 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 166ms/step - loss: 0.6909 - accuracy: 0.5345 - val_loss: 0.6918 - val_accuracy: 0.5433
# Epoch 2/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.6907 - accuracy: 0.5376 - val_loss: 0.6902 - val_accuracy: 0.5433
# Epoch 3/30
# 30/30 [==============================] - 5s 164ms/step - loss: 0.6907 - accuracy: 0.5400 - val_loss: 0.6905 - val_accuracy: 0.5433
# Epoch 4/30
# 30/30 [==============================] - 5s 165ms/step - loss: 0.6907 - accuracy: 0.5403 - val_loss: 0.6909 - val_accuracy: 0.5433
# Epoch 5/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6906 - accuracy: 0.5387 - val_loss: 0.6910 - val_accuracy: 0.5433
# Epoch 6/30
# 30/30 [==============================] - 5s 157ms/step - loss: 0.6933 - accuracy: 0.5289 - val_loss: 0.7020 - val_accuracy: 0.4567
# Epoch 7/30
# 30/30 [==============================] - 5s 161ms/step - loss: 0.6926 - accuracy: 0.5242 - val_loss: 0.6904 - val_accuracy: 0.5433
# Best epoch for Fold 4: 2, Validation Loss: 0.6902, Validation Accuracy: 0.5433, Zero-One Loss: 0.4567
# ==== Training Fold 5 ====
# Epoch 1/30
# 30/30 [==============================] - 5s 167ms/step - loss: 0.6917 - accuracy: 0.5374 - val_loss: 0.6915 - val_accuracy: 0.5529
# Epoch 2/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.6919 - accuracy: 0.5374 - val_loss: 0.6877 - val_accuracy: 0.5529
# Epoch 3/30
# 30/30 [==============================] - 5s 153ms/step - loss: 0.6908 - accuracy: 0.5376 - val_loss: 0.6878 - val_accuracy: 0.5529
# Epoch 4/30
# 30/30 [==============================] - 5s 171ms/step - loss: 0.6914 - accuracy: 0.5387 - val_loss: 0.6876 - val_accuracy: 0.5529
# Epoch 5/30
# 30/30 [==============================] - 5s 154ms/step - loss: 0.6913 - accuracy: 0.5374 - val_loss: 0.6876 - val_accuracy: 0.5529
# Epoch 6/30
# 30/30 [==============================] - 5s 153ms/step - loss: 0.6923 - accuracy: 0.5289 - val_loss: 0.6876 - val_accuracy: 0.5529
# Epoch 7/30
# 30/30 [==============================] - 5s 154ms/step - loss: 0.6907 - accuracy: 0.5360 - val_loss: 0.6908 - val_accuracy: 0.5529
# Epoch 8/30
# 30/30 [==============================] - 5s 165ms/step - loss: 0.6915 - accuracy: 0.5358 - val_loss: 0.6888 - val_accuracy: 0.5529
# Epoch 9/30
# 30/30 [==============================] - 5s 170ms/step - loss: 0.6907 - accuracy: 0.5376 - val_loss: 0.6876 - val_accuracy: 0.5529
# Best epoch for Fold 5: 4, Validation Loss: 0.6876, Validation Accuracy: 0.5529, Zero-One Loss: 0.4471
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
#  Model VGG16_0.1 has been saved.

# %%
def test_loop_optimized(model, x_test, y_test):
    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    zero_one_loss = 1 - accuracy

    print(f'Test Accuracy: {accuracy:.4f}, Zero-One Loss: {zero_one_loss:.4f}')

    y_preds = model.predict(x_test)
    y_preds = np.round(y_preds).astype(int)

    return y_preds

# %%
def load_model_keras(name, root_path='/content/gdrive/My Drive/ml project/'):
    file_path = os.path.join(root_path, f'{name}.h5')
    model = tf.keras.models.load_model(file_path)
    model.summary()
    print(f"Model {name} has been loaded.")
    return model

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt



def plot_and_display_confusion_matrix(cm, classes, normalize=False, title='', cmap=plt.cm.Blues):
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
    else:
        print('Confusion matrix, without normalization')

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()
    plt.show()

def generate_and_display_confusion_matrix(predictions, true_labels, plot=False):
    classes = [0, 1]
    cm = confusion_matrix(true_labels, predictions, labels=classes)
    if plot:
        plot_and_display_confusion_matrix(cm, classes=classes, normalize=False, title='Confusion Matrix')
    return cm

# %%
# Load the trained model
model = load_model_keras('AlexNet_0.005')

# Perform testing
y_preds = test_loop_optimized(model, test_images_loaded, test_labels_loaded)

# Generate and display confusion matrix
generate_and_display_confusion_matrix(y_preds, test_labels_loaded, plot=True)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 16, 16, 96)        34944
#
#  batch_normalization (Batch  (None, 16, 16, 96)        384
#  Normalization)
#
#  max_pooling2d (MaxPooling2  (None, 7, 7, 96)          0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 256)         614656
#
#  batch_normalization_1 (Bat  (None, 7, 7, 256)         1024
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 3, 3, 256)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 3, 3, 384)         885120
#
#  batch_normalization_2 (Bat  (None, 3, 3, 384)         1536
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 3, 3, 384)         1327488
#
#  batch_normalization_3 (Bat  (None, 3, 3, 384)         1536
#  chNormalization)
#
#  conv2d_4 (Conv2D)           (None, 3, 3, 256)         884992
#
#  batch_normalization_4 (Bat  (None, 3, 3, 256)         1024
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 1, 1, 256)         0
#  g2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 4096)              1052672
#
#  dropout (Dropout)           (None, 4096)              0
#
#  dense_1 (Dense)             (None, 4096)              16781312
#
#  dropout_1 (Dropout)         (None, 4096)              0
#
#  dense_2 (Dense)             (None, 1)                 4097
#
# =================================================================
# Total params: 21590785 (82.36 MB)
# Trainable params: 21588033 (82.35 MB)
# Non-trainable params: 2752 (10.75 KB)
# _________________________________________________________________
# Model AlexNet_0.005 has been loaded.
# Test Accuracy: 0.8936, Zero-One Loss: 0.1064
# 37/37 [==============================] - 0s 3ms/step
# Confusion matrix, without normalization
# array([[604,  36],
#        [ 90, 454]])
